# %%
import numpy as np
import matplotlib.pyplot as plt
from backend import TwoDimNav, PC_AC_agent

# %%
train_episodes = 200
test_episodes = 1

tmax = 300
goalsize = 0.25
startcoord = 'center'
goalcoord = [0.7, 0.7]
seed = np.random.choice(np.arange(100),1)
print(seed)
env = TwoDimNav(startcoord=startcoord, goalcoord=goalcoord, goalsize=goalsize, tmax=tmax, seed=seed)
# Out:
# [87]

# %%
# initialize agent
alr = 0.0075  # 0.0075
clr = 0.025  # 0.025

agent = PC_AC_agent(alr=alr, clr=clr)

# %%
# visualize place field at arbitary coordinates
xy = np.array([0,0])
pc = agent.get_pc(xy)
plt.imshow(pc.reshape(agent.npc, agent.npc))

# %%
latency = []
aprob = []
success = 0
tds = []

for e in range(train_episodes):
    state, goal, eucdist, done = env.reset()

    for t in range(tmax):

        onehotg = agent.get_action(state)

        # eucdist is euclediean distance to goal, done is a sparse scalar reward signal 
        newstate, eucdist, done = env.step(onehotg) 

        # use scalar sparse reward signal to update TD error
        agent.learn(newstate=newstate, reward=done)

        tds.append(agent.td)

        state = newstate.copy()

        if done:
            success+=1
            break
            
    if e % 25 == 0:
        agent.plot_maps(env)

    latency.append(t)
    #print(agent.wC.max(), agent.wA.max())
    print(f'E {e+1}/ {train_episodes}, R {done}, t {t}')


print(f"Completion {success}/{train_episodes}")
# Out:
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 1/ 200, R True, t 198
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 2/ 200, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 3/ 200, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 4/ 200, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 5/ 200, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 6/ 200, R True, t 37
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 7/ 200, R True, t 201
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 8/ 200, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 9/ 200, R True, t 126
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 10/ 200, R True, t 108
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 11/ 200, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 12/ 200, R True, t 193
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 13/ 200, R True, t 24
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 14/ 200, R True, t 124
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 15/ 200, R True, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 16/ 200, R True, t 19
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 17/ 200, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 18/ 200, R True, t 22
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 19/ 200, R True, t 40
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 20/ 200, R True, t 35
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 21/ 200, R True, t 27
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 22/ 200, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 23/ 200, R True, t 51
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 24/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 25/ 200, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 26/ 200, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 27/ 200, R True, t 33
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 28/ 200, R True, t 18
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 29/ 200, R True, t 21
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 30/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 31/ 200, R True, t 49
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 32/ 200, R True, t 22
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 33/ 200, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 34/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 35/ 200, R True, t 46
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 36/ 200, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 37/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 38/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 39/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 40/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 41/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 42/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 43/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 44/ 200, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 45/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 46/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 47/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 48/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 49/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 50/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 51/ 200, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 52/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 53/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 54/ 200, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 55/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 56/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 57/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 58/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 59/ 200, R True, t 20
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 60/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 61/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 62/ 200, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 63/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 64/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 65/ 200, R True, t 18
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 66/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 67/ 200, R True, t 39
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 68/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 69/ 200, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 70/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 71/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 72/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 73/ 200, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 74/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 75/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 76/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 77/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 78/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 79/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 80/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 81/ 200, R True, t 33
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 82/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 83/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 84/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 85/ 200, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 86/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 87/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 88/ 200, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 89/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 90/ 200, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 91/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 92/ 200, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 93/ 200, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 94/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 95/ 200, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 96/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 97/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 98/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 99/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 100/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 101/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 102/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 103/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 104/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 105/ 200, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 106/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 107/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 108/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 109/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 110/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 111/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 112/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 113/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 114/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 115/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 116/ 200, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 117/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 118/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 119/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 120/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 121/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 122/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 123/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 124/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 125/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 126/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 127/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 128/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 129/ 200, R True, t 32
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 130/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 131/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 132/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 133/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 134/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 135/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 136/ 200, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 137/ 200, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 138/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 139/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 140/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 141/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 142/ 200, R True, t 17
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 143/ 200, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 144/ 200, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 145/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 146/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 147/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 148/ 200, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 149/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 150/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 151/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 152/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 153/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 154/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 155/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 156/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 157/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 158/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 159/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 160/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 161/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 162/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 163/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 164/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 165/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 166/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 167/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 168/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 169/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 170/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 171/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 172/ 200, R True, t 21
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 173/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 174/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 175/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 176/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 177/ 200, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 178/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 179/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 180/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 181/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 182/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 183/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 184/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 185/ 200, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 186/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 187/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 188/ 200, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 189/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 190/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 191/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 192/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 193/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 194/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 195/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 196/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 197/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 198/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 199/ 200, R True, t 8
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 200/ 200, R True, t 8
# Completion 196/200

# %%
env.plot_trajectory()

# %%
# plot value and policy maps
agent.plot_maps(env)

# %%
# Test adaptability of learned policy with new goal location 
test_episodes = 100

startcoord = 'center'
goalcoord = [-0.7,-0.7]
seed = np.random.choice(np.arange(100),1)
print(seed)
testenv = TwoDimNav(startcoord=startcoord, goalcoord=goalcoord, goalsize=goalsize, tmax=tmax, seed=seed)
# Out:
# [72]

# %%
# reuse trained agent

testlatency = []
testsuccess = 0
testtds = []

for e in range(test_episodes):
    state, goal, eucdist, done = testenv.reset()

    for t in range(tmax):

        onehotg = agent.get_action(state)

        # eucdist is euclediean distance to goal, done is a sparse scalar reward signal 
        newstate, eucdist, done = testenv.step(onehotg) 

        # use scalar sparse reward signal to update TD error
        agent.learn(newstate=newstate, reward=done)

        testtds.append(agent.td)

        state = newstate.copy()

        if done:
            testsuccess+=1
            break

    testlatency.append(t)
    #print(agent.wC.max(), agent.wA.max())
    print(f'E {e+1}/ {test_episodes}, R {done}, t {t}')
    

print(f"Completion {testsuccess}/{test_episodes}")
# Out:
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 1/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 2/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 3/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 4/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 5/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 6/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 7/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 8/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 9/ 100, R True, t 34
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 10/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 11/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 12/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 13/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 14/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 15/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 16/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 17/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 18/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 19/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 20/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 21/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 22/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 23/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 24/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 25/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 26/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 27/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 28/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 29/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 30/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 31/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 32/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 33/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 34/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 35/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 36/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 37/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 38/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 39/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 40/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 41/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 42/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 43/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 44/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 45/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 46/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 47/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 48/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 49/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 50/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 51/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 52/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 53/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 54/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 55/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 56/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 57/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 58/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 59/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 60/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 61/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 62/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 63/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 64/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 65/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 66/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 67/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 68/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 69/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 70/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 71/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 72/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 73/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 74/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 75/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 76/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 77/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 78/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 79/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 80/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 81/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 82/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 83/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 84/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 85/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 86/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 87/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 88/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 89/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 90/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 91/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 92/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 93/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 94/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 95/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 96/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 97/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 98/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 99/ 100, R False, t 299
# [0. 0.]
# State: [0. 0.], Goal: [-0.7 -0.7]
# E 100/ 100, R False, t 299
# Completion 1/100

# %%
testenv.plot_trajectory()

# %%
# plot value and policy maps, value maps usually shift faster than actor policy
agent.plot_maps(testenv)

# %%
# plot latency to reach goal
plt.figure()
plt.plot(latency,label='Train')
plt.plot(testlatency, label='Test')
plt.legend()
plt.xlabel('Trial')
plt.ylabel('Steps')
plt.title(f"Completion: Train:{success}/{train_episodes}, Test: {testsuccess}/{test_episodes}")
# Out:
# Text(0.5, 1.0, 'Completion: Train:196/200, Test: 1/100')

# %%
# plot latency to reach goal
plt.figure()
plt.plot(tds,label='Train')
#plt.plot(testtds, label='Test')
plt.legend()
plt.xlabel('Steps')
plt.ylabel('TD Error')
plt.title(f"Temporal Difference Error")
# Out:
# Text(0.5, 1.0, 'Temporal Difference Error')
