# %%
import numpy as np
import matplotlib.pyplot as plt
from backend import TwoDimNav, PC_AC_agent

# %%
train_episodes = 1000

tmax = 100
goalsize = 0.25
startcoord = 'center'
goalcoord = [0.7, 0.7]
testgoalcoord = [-0.7,-0.7]

seed = np.random.choice(np.arange(100),1)  # choose a specific seed for consistency
print(seed)
env = TwoDimNav(startcoord=startcoord, goalcoord=goalcoord, goalsize=goalsize, tmax=tmax, seed=seed)
# Out:
# [86]

# %%
# initialize agent
alr = 0.00  # 0.0075
clr = 0.001  # 0.025

agent = PC_AC_agent(alr=alr, clr=clr)

# %%
wClms = agent.wC.copy()
lmslr = 0.01

# %%
latency = []
aprob = []
success = 0
hebbtds = []
lmstds = []

features = []
hebbvals = []
lmsvals = []
for e in range(train_episodes):
    state, goal, eucdist, done = env.reset()

    hebbval = []
    lmsval = []
    hebbtd = []
    lmstd = []
    storehtd = []
    feature = []

    for t in range(tmax):
    
        onehotg = agent.get_action(state)

        feature.append(state)

        # eucdist is euclediean distance to goal, done is a sparse scalar reward signal 
        newstate, eucdist, done = env.step(onehotg) 

        # use scalar sparse reward signal to update TD error
        agent.learn(newstate=newstate, reward=done)


        # LMS update end of trial
        V = np.matmul(agent.get_pc(state), wClms)
        V1 = np.matmul(agent.get_pc(newstate), wClms)
        td = int(done) + agent.gamma * V1 - V

        # store value
        hebbval.append(agent.V)
        lmsval.append(V)

        hebbtd.append(agent.td)
        lmstd.append(td)

        storehtd.append(agent.h[:,None]*td)

        state = newstate.copy()

        if done:
            success+=1
            break
            
    # if e % 25 == 0:
    #     agent.plot_maps(env)

    hebbvals.append(hebbval)
    lmsvals.append(lmsval)

    hebbtds.append(hebbtd)
    lmstds.append(lmstd)
    features.append(feature)

    # update lms
    wClms += lmslr * np.mean(np.array(storehtd),axis=0)

    latency.append(t)
    #print(agent.wC.max(), agent.wA.max())
    print(f'E {e+1}/ {train_episodes}, R {done}, t {t}')


print(f"Completion {success}/{train_episodes}")
# Out:
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 1/ 1000, R True, t 55
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 2/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 3/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 4/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 5/ 1000, R True, t 79
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 6/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 7/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 8/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 9/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 10/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 11/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 12/ 1000, R True, t 55
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 13/ 1000, R True, t 25
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 14/ 1000, R True, t 79
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 15/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 16/ 1000, R True, t 53
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 17/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 18/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 19/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 20/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 21/ 1000, R True, t 42
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 22/ 1000, R True, t 41
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 23/ 1000, R True, t 76
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 24/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 25/ 1000, R True, t 49
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 26/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 27/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 28/ 1000, R True, t 38
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 29/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 30/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 31/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 32/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 33/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 34/ 1000, R True, t 57
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 35/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 36/ 1000, R True, t 30
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 37/ 1000, R True, t 30
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 38/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 39/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 40/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 41/ 1000, R True, t 89
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 42/ 1000, R True, t 45
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 43/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 44/ 1000, R True, t 92
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 45/ 1000, R True, t 87
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 46/ 1000, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 47/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 48/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 49/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 50/ 1000, R True, t 23
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 51/ 1000, R True, t 95
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 52/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 53/ 1000, R True, t 77
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 54/ 1000, R True, t 92
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 55/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 56/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 57/ 1000, R True, t 45
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 58/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 59/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 60/ 1000, R True, t 26
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 61/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 62/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 63/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 64/ 1000, R True, t 87
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 65/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 66/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 67/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 68/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 69/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 70/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 71/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 72/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 73/ 1000, R True, t 98
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 74/ 1000, R True, t 32
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 75/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 76/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 77/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 78/ 1000, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 79/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 80/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 81/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 82/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 83/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 84/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 85/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 86/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 87/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 88/ 1000, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 89/ 1000, R True, t 38
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 90/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 91/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 92/ 1000, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 93/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 94/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 95/ 1000, R True, t 89
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 96/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 97/ 1000, R True, t 76
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 98/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 99/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 100/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 101/ 1000, R True, t 32
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 102/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 103/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 104/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 105/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 106/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 107/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 108/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 109/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 110/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 111/ 1000, R True, t 33
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 112/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 113/ 1000, R True, t 70
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 114/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 115/ 1000, R True, t 73
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 116/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 117/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 118/ 1000, R True, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 119/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 120/ 1000, R True, t 75
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 121/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 122/ 1000, R True, t 69
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 123/ 1000, R True, t 32
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 124/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 125/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 126/ 1000, R True, t 67
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 127/ 1000, R True, t 86
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 128/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 129/ 1000, R True, t 90
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 130/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 131/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 132/ 1000, R True, t 31
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 133/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 134/ 1000, R True, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 135/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 136/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 137/ 1000, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 138/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 139/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 140/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 141/ 1000, R True, t 56
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 142/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 143/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 144/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 145/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 146/ 1000, R True, t 53
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 147/ 1000, R True, t 68
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 148/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 149/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 150/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 151/ 1000, R True, t 97
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 152/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 153/ 1000, R True, t 65
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 154/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 155/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 156/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 157/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 158/ 1000, R True, t 20
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 159/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 160/ 1000, R True, t 25
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 161/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 162/ 1000, R True, t 58
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 163/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 164/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 165/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 166/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 167/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 168/ 1000, R True, t 55
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 169/ 1000, R True, t 21
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 170/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 171/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 172/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 173/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 174/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 175/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 176/ 1000, R True, t 25
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 177/ 1000, R True, t 73
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 178/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 179/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 180/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 181/ 1000, R True, t 64
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 182/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 183/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 184/ 1000, R True, t 38
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 185/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 186/ 1000, R True, t 45
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 187/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 188/ 1000, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 189/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 190/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 191/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 192/ 1000, R True, t 43
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 193/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 194/ 1000, R True, t 45
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 195/ 1000, R True, t 90
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 196/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 197/ 1000, R True, t 53
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 198/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 199/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 200/ 1000, R True, t 87
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 201/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 202/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 203/ 1000, R True, t 38
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 204/ 1000, R True, t 86
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 205/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 206/ 1000, R True, t 51
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 207/ 1000, R True, t 94
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 208/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 209/ 1000, R True, t 84
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 210/ 1000, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 211/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 212/ 1000, R True, t 64
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 213/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 214/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 215/ 1000, R True, t 51
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 216/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 217/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 218/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 219/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 220/ 1000, R True, t 34
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 221/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 222/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 223/ 1000, R True, t 29
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 224/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 225/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 226/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 227/ 1000, R True, t 94
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 228/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 229/ 1000, R True, t 24
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 230/ 1000, R True, t 75
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 231/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 232/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 233/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 234/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 235/ 1000, R True, t 77
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 236/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 237/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 238/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 239/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 240/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 241/ 1000, R True, t 96
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 242/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 243/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 244/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 245/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 246/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 247/ 1000, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 248/ 1000, R True, t 59
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 249/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 250/ 1000, R True, t 57
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 251/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 252/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 253/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 254/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 255/ 1000, R True, t 44
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 256/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 257/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 258/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 259/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 260/ 1000, R True, t 23
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 261/ 1000, R True, t 33
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 262/ 1000, R True, t 18
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 263/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 264/ 1000, R True, t 32
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 265/ 1000, R True, t 67
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 266/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 267/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 268/ 1000, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 269/ 1000, R True, t 57
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 270/ 1000, R True, t 19
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 271/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 272/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 273/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 274/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 275/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 276/ 1000, R True, t 50
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 277/ 1000, R True, t 62
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 278/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 279/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 280/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 281/ 1000, R True, t 20
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 282/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 283/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 284/ 1000, R True, t 89
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 285/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 286/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 287/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 288/ 1000, R True, t 25
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 289/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 290/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 291/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 292/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 293/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 294/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 295/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 296/ 1000, R True, t 30
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 297/ 1000, R True, t 66
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 298/ 1000, R True, t 27
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 299/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 300/ 1000, R True, t 87
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 301/ 1000, R True, t 82
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 302/ 1000, R True, t 21
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 303/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 304/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 305/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 306/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 307/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 308/ 1000, R True, t 90
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 309/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 310/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 311/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 312/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 313/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 314/ 1000, R True, t 96
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 315/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 316/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 317/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 318/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 319/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 320/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 321/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 322/ 1000, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 323/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 324/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 325/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 326/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 327/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 328/ 1000, R True, t 62
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 329/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 330/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 331/ 1000, R True, t 44
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 332/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 333/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 334/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 335/ 1000, R True, t 40
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 336/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 337/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 338/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 339/ 1000, R True, t 49
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 340/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 341/ 1000, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 342/ 1000, R True, t 81
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 343/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 344/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 345/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 346/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 347/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 348/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 349/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 350/ 1000, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 351/ 1000, R True, t 66
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 352/ 1000, R True, t 46
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 353/ 1000, R True, t 40
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 354/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 355/ 1000, R True, t 77
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 356/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 357/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 358/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 359/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 360/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 361/ 1000, R True, t 64
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 362/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 363/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 364/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 365/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 366/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 367/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 368/ 1000, R True, t 96
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 369/ 1000, R True, t 32
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 370/ 1000, R True, t 46
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 371/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 372/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 373/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 374/ 1000, R True, t 19
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 375/ 1000, R True, t 43
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 376/ 1000, R True, t 22
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 377/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 378/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 379/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 380/ 1000, R True, t 55
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 381/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 382/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 383/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 384/ 1000, R True, t 36
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 385/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 386/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 387/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 388/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 389/ 1000, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 390/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 391/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 392/ 1000, R True, t 60
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 393/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 394/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 395/ 1000, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 396/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 397/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 398/ 1000, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 399/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 400/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 401/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 402/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 403/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 404/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 405/ 1000, R True, t 30
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 406/ 1000, R True, t 41
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 407/ 1000, R True, t 89
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 408/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 409/ 1000, R True, t 72
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 410/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 411/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 412/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 413/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 414/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 415/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 416/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 417/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 418/ 1000, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 419/ 1000, R True, t 63
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 420/ 1000, R True, t 57
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 421/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 422/ 1000, R True, t 42
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 423/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 424/ 1000, R True, t 68
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 425/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 426/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 427/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 428/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 429/ 1000, R True, t 95
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 430/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 431/ 1000, R True, t 76
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 432/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 433/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 434/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 435/ 1000, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 436/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 437/ 1000, R True, t 28
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 438/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 439/ 1000, R True, t 42
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 440/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 441/ 1000, R True, t 17
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 442/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 443/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 444/ 1000, R True, t 66
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 445/ 1000, R True, t 36
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 446/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 447/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 448/ 1000, R True, t 44
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 449/ 1000, R True, t 73
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 450/ 1000, R True, t 93
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 451/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 452/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 453/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 454/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 455/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 456/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 457/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 458/ 1000, R True, t 40
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 459/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 460/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 461/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 462/ 1000, R True, t 77
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 463/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 464/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 465/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 466/ 1000, R True, t 40
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 467/ 1000, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 468/ 1000, R True, t 64
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 469/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 470/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 471/ 1000, R True, t 35
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 472/ 1000, R True, t 27
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 473/ 1000, R True, t 18
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 474/ 1000, R True, t 79
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 475/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 476/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 477/ 1000, R True, t 20
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 478/ 1000, R True, t 69
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 479/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 480/ 1000, R True, t 62
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 481/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 482/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 483/ 1000, R True, t 24
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 484/ 1000, R True, t 39
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 485/ 1000, R True, t 31
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 486/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 487/ 1000, R True, t 85
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 488/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 489/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 490/ 1000, R True, t 44
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 491/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 492/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 493/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 494/ 1000, R True, t 32
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 495/ 1000, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 496/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 497/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 498/ 1000, R True, t 62
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 499/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 500/ 1000, R True, t 35
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 501/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 502/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 503/ 1000, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 504/ 1000, R True, t 47
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 505/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 506/ 1000, R True, t 63
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 507/ 1000, R True, t 27
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 508/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 509/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 510/ 1000, R True, t 60
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 511/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 512/ 1000, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 513/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 514/ 1000, R True, t 21
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 515/ 1000, R True, t 42
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 516/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 517/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 518/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 519/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 520/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 521/ 1000, R True, t 65
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 522/ 1000, R True, t 18
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 523/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 524/ 1000, R True, t 53
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 525/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 526/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 527/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 528/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 529/ 1000, R True, t 92
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 530/ 1000, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 531/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 532/ 1000, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 533/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 534/ 1000, R True, t 36
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 535/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 536/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 537/ 1000, R True, t 53
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 538/ 1000, R True, t 63
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 539/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 540/ 1000, R True, t 92
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 541/ 1000, R True, t 78
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 542/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 543/ 1000, R True, t 52
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 544/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 545/ 1000, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 546/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 547/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 548/ 1000, R True, t 68
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 549/ 1000, R True, t 22
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 550/ 1000, R True, t 42
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 551/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 552/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 553/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 554/ 1000, R True, t 60
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 555/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 556/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 557/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 558/ 1000, R True, t 89
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 559/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 560/ 1000, R True, t 97
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 561/ 1000, R True, t 76
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 562/ 1000, R True, t 23
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 563/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 564/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 565/ 1000, R True, t 71
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 566/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 567/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 568/ 1000, R True, t 19
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 569/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 570/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 571/ 1000, R True, t 81
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 572/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 573/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 574/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 575/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 576/ 1000, R True, t 27
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 577/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 578/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 579/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 580/ 1000, R True, t 33
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 581/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 582/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 583/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 584/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 585/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 586/ 1000, R True, t 57
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 587/ 1000, R True, t 62
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 588/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 589/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 590/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 591/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 592/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 593/ 1000, R True, t 36
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 594/ 1000, R True, t 83
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 595/ 1000, R True, t 28
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 596/ 1000, R True, t 25
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 597/ 1000, R True, t 23
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 598/ 1000, R True, t 26
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 599/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 600/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 601/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 602/ 1000, R True, t 40
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 603/ 1000, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 604/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 605/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 606/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 607/ 1000, R True, t 39
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 608/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 609/ 1000, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 610/ 1000, R True, t 72
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 611/ 1000, R True, t 98
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 612/ 1000, R True, t 64
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 613/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 614/ 1000, R True, t 47
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 615/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 616/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 617/ 1000, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 618/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 619/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 620/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 621/ 1000, R True, t 50
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 622/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 623/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 624/ 1000, R True, t 96
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 625/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 626/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 627/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 628/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 629/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 630/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 631/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 632/ 1000, R True, t 29
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 633/ 1000, R True, t 22
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 634/ 1000, R True, t 20
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 635/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 636/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 637/ 1000, R True, t 28
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 638/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 639/ 1000, R True, t 96
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 640/ 1000, R True, t 72
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 641/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 642/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 643/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 644/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 645/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 646/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 647/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 648/ 1000, R True, t 35
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 649/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 650/ 1000, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 651/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 652/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 653/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 654/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 655/ 1000, R True, t 69
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 656/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 657/ 1000, R True, t 70
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 658/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 659/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 660/ 1000, R True, t 11
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 661/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 662/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 663/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 664/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 665/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 666/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 667/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 668/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 669/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 670/ 1000, R True, t 57
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 671/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 672/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 673/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 674/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 675/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 676/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 677/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 678/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 679/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 680/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 681/ 1000, R True, t 51
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 682/ 1000, R True, t 46
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 683/ 1000, R True, t 75
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 684/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 685/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 686/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 687/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 688/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 689/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 690/ 1000, R True, t 28
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 691/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 692/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 693/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 694/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 695/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 696/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 697/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 698/ 1000, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 699/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 700/ 1000, R True, t 18
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 701/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 702/ 1000, R True, t 26
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 703/ 1000, R True, t 36
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 704/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 705/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 706/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 707/ 1000, R True, t 28
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 708/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 709/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 710/ 1000, R True, t 59
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 711/ 1000, R True, t 30
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 712/ 1000, R True, t 44
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 713/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 714/ 1000, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 715/ 1000, R True, t 66
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 716/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 717/ 1000, R True, t 49
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 718/ 1000, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 719/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 720/ 1000, R True, t 24
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 721/ 1000, R True, t 24
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# ...
# E 761/ 1000, R True, t 48
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 762/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 763/ 1000, R True, t 25
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 764/ 1000, R True, t 17
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 765/ 1000, R True, t 29
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 766/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 767/ 1000, R True, t 66
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 768/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 769/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 770/ 1000, R True, t 48
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 771/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 772/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 773/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 774/ 1000, R True, t 28
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 775/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 776/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 777/ 1000, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 778/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 779/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 780/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 781/ 1000, R True, t 66
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 782/ 1000, R True, t 89
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 783/ 1000, R True, t 78
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 784/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 785/ 1000, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 786/ 1000, R True, t 96
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 787/ 1000, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 788/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 789/ 1000, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 790/ 1000, R True, t 77
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 791/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 792/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 793/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 794/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 795/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 796/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 797/ 1000, R True, t 98
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 798/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 799/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 800/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 801/ 1000, R True, t 34
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 802/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 803/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 804/ 1000, R True, t 75
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 805/ 1000, R True, t 43
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 806/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 807/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 808/ 1000, R True, t 70
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 809/ 1000, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 810/ 1000, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 811/ 1000, R True, t 25
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 812/ 1000, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 813/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 814/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 815/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 816/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 817/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 818/ 1000, R True, t 66
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 819/ 1000, R True, t 58
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 820/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 821/ 1000, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 822/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 823/ 1000, R True, t 17
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 824/ 1000, R True, t 96
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 825/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 826/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 827/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 828/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 829/ 1000, R True, t 70
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 830/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 831/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 832/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 833/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 834/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 835/ 1000, R True, t 84
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 836/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 837/ 1000, R True, t 35
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 838/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 839/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 840/ 1000, R True, t 14
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 841/ 1000, R True, t 37
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 842/ 1000, R True, t 65
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 843/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 844/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 845/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 846/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 847/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 848/ 1000, R True, t 24
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 849/ 1000, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 850/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 851/ 1000, R True, t 47
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 852/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 853/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 854/ 1000, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 855/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 856/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 857/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 858/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 859/ 1000, R True, t 25
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 860/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 861/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 862/ 1000, R True, t 9
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 863/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 864/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 865/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 866/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 867/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 868/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 869/ 1000, R True, t 90
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 870/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 871/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 872/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 873/ 1000, R True, t 13
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 874/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 875/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 876/ 1000, R True, t 12
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 877/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 878/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 879/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 880/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 881/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 882/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 883/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 884/ 1000, R True, t 35
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 885/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 886/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 887/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 888/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 889/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 890/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 891/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 892/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 893/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 894/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 895/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 896/ 1000, R True, t 82
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 897/ 1000, R True, t 35
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 898/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 899/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 900/ 1000, R True, t 81
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 901/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 902/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 903/ 1000, R True, t 15
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 904/ 1000, R True, t 92
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 905/ 1000, R True, t 91
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 906/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 907/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 908/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 909/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 910/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 911/ 1000, R True, t 46
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 912/ 1000, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 913/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 914/ 1000, R True, t 77
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 915/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 916/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 917/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 918/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 919/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 920/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 921/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 922/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 923/ 1000, R True, t 91
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 924/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 925/ 1000, R True, t 46
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 926/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 927/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 928/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 929/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 930/ 1000, R True, t 53
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 931/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 932/ 1000, R True, t 29
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 933/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 934/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 935/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 936/ 1000, R True, t 82
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 937/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 938/ 1000, R True, t 95
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 939/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 940/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 941/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 942/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 943/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 944/ 1000, R True, t 73
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 945/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 946/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 947/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 948/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 949/ 1000, R True, t 49
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 950/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 951/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 952/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 953/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 954/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 955/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 956/ 1000, R True, t 73
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 957/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 958/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 959/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 960/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 961/ 1000, R True, t 85
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 962/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 963/ 1000, R True, t 66
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 964/ 1000, R True, t 10
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 965/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 966/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 967/ 1000, R True, t 24
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 968/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 969/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 970/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 971/ 1000, R True, t 19
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 972/ 1000, R True, t 84
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 973/ 1000, R True, t 83
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 974/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 975/ 1000, R True, t 36
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 976/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 977/ 1000, R True, t 61
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 978/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 979/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 980/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 981/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 982/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 983/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 984/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 985/ 1000, R True, t 90
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 986/ 1000, R True, t 40
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 987/ 1000, R True, t 19
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 988/ 1000, R True, t 59
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 989/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 990/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 991/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 992/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 993/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 994/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 995/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 996/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 997/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 998/ 1000, R True, t 16
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 999/ 1000, R False, t 99
# [0. 0.]
# State: [0. 0.], Goal: [0.7 0.7]
# E 1000/ 1000, R False, t 99
# Completion 350/1000

# %%
# get true V for all episodes
hebbval_hats = []
lmsval_hats = []
hebberr = []
lmserr = []

for e in range(train_episodes):
    hebbval_hat = []
    lmsval_hat = []
    for i, feature in enumerate(features[e]):
        h = agent.get_pc(feature)

        hebbval_hat.append(np.matmul(h, agent.wC))
        lmsval_hat.append(np.matmul(h, wClms))

    hebbval_hats.append(hebbval_hat)
    lmsval_hats.append(lmsval_hat)

    hebberr.append(np.mean((np.array(hebbval_hats[e]) - np.array(hebbvals[e]))**2))
    lmserr.append(np.mean((np.array(lmsval_hats[e]) - np.array(lmsvals[e]))**2))

# %%
plt.figure()
plt.imshow(agent.wC.reshape(agent.npc, agent.npc), origin='lower')
plt.colorbar()

# %%
plt.figure()
plt.imshow(wClms.reshape(agent.npc, agent.npc), origin='lower')
plt.colorbar()

# %%
plt.figure()
plt.plot(lmserr,alpha=0.2)
plt.plot(hebberr,alpha=0.2)
