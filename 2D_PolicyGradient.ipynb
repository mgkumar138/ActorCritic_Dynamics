# %% [markdown]
# Code to train an Policy Gradient agent to navigate to a target in a continuous 2D arena
# Code by: M Ganesh Kumar & Blake Bordeleon
# Date: 02/15/2024

# %%
import numpy as np
import matplotlib.pyplot as plt
from backend import TwoDimNav, plot_maps, get_onehot_action
import jax.numpy as jnp
from jax_backend import *

# %%
#initialize environment
train_episodes = 1000
tmax = 100
goalsize = 0.25
startcoord = [0.0,0.0]
goalcoord = [0.7, 0.7]
testgoalcoord = [-0.7,-0.7]

env = TwoDimNav(startcoord=startcoord, goalcoord=goalcoord, goalsize=goalsize, tmax=tmax)
# Out:
# [0.0, 0.0]

# %%
# initialize agent
alr = 0.001  # 0.005

nact = 4
gamma = 0.95
normreward = False # whether to normalize reward for policy gradient

npc = 21
pc_sigma = 0.25
seed = 2023

params = get_parameters(npc, nact, random.PRNGKey(seed), scale=pc_sigma)
initparams = params.copy()
# Out:
# Metal device set to: Apple M2 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2024-02-15 20:51:15.600261: W pjrt_plugin/src/mps_client.cc:535] WARNING: JAX Apple GPU support is experimental and not all JAX functionality is correctly supported!

# %%
# inner loop training loop
def run_trial(params, env):
    coords = []
    actions = []
    rewards = []

    state, goal, eucdist, done = env.reset()

    for t in range(tmax):

        pcact = predict_placecell(params, state[None,:])

        aprob = predict_action(params, pcact)

        onehotg = get_onehot_action(aprob)

        newstate, eucdist, done = env.step(onehotg) 

        reward = int(done)

        coords.append(state)
        actions.append(onehotg)
        rewards.append(reward)

        state = newstate.copy()

        if done:
            print(f'Target reached at {t} step')
            break

    #print(f'Trial {t+1}/ {train_episodes}, R {done}, t {t}')

    return jnp.array(coords), jnp.array(rewards), jnp.array(actions), t

# %%
latencys = []
gradients = []
successes = []
env = TwoDimNav(startcoord=startcoord, goalcoord=goalcoord, goalsize=goalsize, tmax=tmax)

for e in range(train_episodes):

    coords, rewards, actions, latency = run_trial(params, env)
    discount_rewards = get_discounted_rewards(rewards, gamma=gamma, norm=normreward)
    
    params, grads = update_params(params, coords, actions, discount_rewards, alr)
    
    dcent, dsig, dconst, dact, dcri = grads
    #print(dcent.max(), dsig.max(),dconst.max(), dact.max())
    
    latencys.append(latency)
    gradients.append([np.linalg.norm(dact),np.linalg.norm(dcri), np.linalg.norm(dconst),np.linalg.norm(dsig), np.linalg.norm(dcent)])
    
    if e % 100 == 0:
        plot_maps(env, npc, params[3], title=f'Map at Episode {e+1}')
    
    print(f'E {e+1}/{train_episodes} in {latency} steps')
# Out:
# [0.0, 0.0]
# Target reached at 46 step
# E 1/1000 in 46 steps
# Target reached at 64 step
# E 2/1000 in 64 steps
# E 3/1000 in 99 steps
# E 4/1000 in 99 steps
# Target reached at 89 step
# E 5/1000 in 89 steps
# E 6/1000 in 99 steps
# E 7/1000 in 99 steps
# Target reached at 29 step
# E 8/1000 in 29 steps
# E 9/1000 in 99 steps
# E 10/1000 in 99 steps
# Target reached at 15 step
# E 11/1000 in 15 steps
# Target reached at 10 step
# E 12/1000 in 10 steps
# E 13/1000 in 99 steps
# E 14/1000 in 99 steps
# E 15/1000 in 99 steps
# Target reached at 39 step
# E 16/1000 in 39 steps
# Target reached at 33 step
# E 17/1000 in 33 steps
# E 18/1000 in 99 steps
# Target reached at 72 step
# E 19/1000 in 72 steps
# E 20/1000 in 99 steps
# Target reached at 42 step
# E 21/1000 in 42 steps
# E 22/1000 in 99 steps
# Target reached at 52 step
# E 23/1000 in 52 steps
# Target reached at 27 step
# E 24/1000 in 27 steps
# E 25/1000 in 99 steps
# E 26/1000 in 99 steps
# E 27/1000 in 99 steps
# Target reached at 24 step
# E 28/1000 in 24 steps
# E 29/1000 in 99 steps
# E 30/1000 in 99 steps
# Target reached at 15 step
# E 31/1000 in 15 steps
# Target reached at 16 step
# E 32/1000 in 16 steps
# Target reached at 28 step
# E 33/1000 in 28 steps
# Target reached at 29 step
# E 34/1000 in 29 steps
# E 35/1000 in 99 steps
# E 36/1000 in 99 steps
# Target reached at 17 step
# E 37/1000 in 17 steps
# Target reached at 61 step
# E 38/1000 in 61 steps
# Target reached at 99 step
# E 39/1000 in 99 steps
# Target reached at 16 step
# E 40/1000 in 16 steps
# Target reached at 36 step
# E 41/1000 in 36 steps
# E 42/1000 in 99 steps
# Target reached at 11 step
# E 43/1000 in 11 steps
# Target reached at 34 step
# E 44/1000 in 34 steps
# Target reached at 43 step
# E 45/1000 in 43 steps
# Target reached at 32 step
# E 46/1000 in 32 steps
# Target reached at 21 step
# E 47/1000 in 21 steps
# Target reached at 44 step
# E 48/1000 in 44 steps
# Target reached at 77 step
# E 49/1000 in 77 steps
# Target reached at 66 step
# E 50/1000 in 66 steps
# Target reached at 46 step
# E 51/1000 in 46 steps
# Target reached at 44 step
# E 52/1000 in 44 steps
# Target reached at 33 step
# E 53/1000 in 33 steps
# Target reached at 10 step
# E 54/1000 in 10 steps
# Target reached at 91 step
# E 55/1000 in 91 steps
# Target reached at 12 step
# E 56/1000 in 12 steps
# Target reached at 13 step
# E 57/1000 in 13 steps
# Target reached at 27 step
# E 58/1000 in 27 steps
# Target reached at 16 step
# E 59/1000 in 16 steps
# Target reached at 17 step
# E 60/1000 in 17 steps
# Target reached at 28 step
# E 61/1000 in 28 steps
# Target reached at 13 step
# E 62/1000 in 13 steps
# Target reached at 21 step
# E 63/1000 in 21 steps
# Target reached at 10 step
# E 64/1000 in 10 steps
# Target reached at 37 step
# E 65/1000 in 37 steps
# Target reached at 77 step
# E 66/1000 in 77 steps
# Target reached at 9 step
# E 67/1000 in 9 steps
# Target reached at 10 step
# E 68/1000 in 10 steps
# Target reached at 50 step
# E 69/1000 in 50 steps
# E 70/1000 in 99 steps
# Target reached at 11 step
# E 71/1000 in 11 steps
# Target reached at 15 step
# E 72/1000 in 15 steps
# Target reached at 13 step
# E 73/1000 in 13 steps
# Target reached at 10 step
# E 74/1000 in 10 steps
# Target reached at 59 step
# E 75/1000 in 59 steps
# Target reached at 22 step
# E 76/1000 in 22 steps
# Target reached at 17 step
# E 77/1000 in 17 steps
# Target reached at 18 step
# E 78/1000 in 18 steps
# Target reached at 9 step
# E 79/1000 in 9 steps
# Target reached at 15 step
# E 80/1000 in 15 steps
# Target reached at 13 step
# E 81/1000 in 13 steps
# Target reached at 24 step
# E 82/1000 in 24 steps
# Target reached at 18 step
# E 83/1000 in 18 steps
# Target reached at 10 step
# E 84/1000 in 10 steps
# Target reached at 14 step
# E 85/1000 in 14 steps
# Target reached at 23 step
# E 86/1000 in 23 steps
# Target reached at 8 step
# E 87/1000 in 8 steps
# Target reached at 64 step
# E 88/1000 in 64 steps
# Target reached at 29 step
# E 89/1000 in 29 steps
# Target reached at 55 step
# E 90/1000 in 55 steps
# Target reached at 16 step
# E 91/1000 in 16 steps
# Target reached at 18 step
# E 92/1000 in 18 steps
# Target reached at 54 step
# E 93/1000 in 54 steps
# Target reached at 15 step
# E 94/1000 in 15 steps
# Target reached at 17 step
# E 95/1000 in 17 steps
# Target reached at 23 step
# E 96/1000 in 23 steps
# Target reached at 21 step
# E 97/1000 in 21 steps
# Target reached at 9 step
# E 98/1000 in 9 steps
# Target reached at 12 step
# E 99/1000 in 12 steps
# Target reached at 9 step
# E 100/1000 in 9 steps
# Target reached at 21 step
# E 101/1000 in 21 steps
# Target reached at 10 step
# E 102/1000 in 10 steps
# Target reached at 10 step
# E 103/1000 in 10 steps
# Target reached at 11 step
# E 104/1000 in 11 steps
# Target reached at 24 step
# E 105/1000 in 24 steps
# Target reached at 11 step
# E 106/1000 in 11 steps
# Target reached at 8 step
# E 107/1000 in 8 steps
# Target reached at 9 step
# E 108/1000 in 9 steps
# Target reached at 9 step
# E 109/1000 in 9 steps
# Target reached at 22 step
# E 110/1000 in 22 steps
# Target reached at 19 step
# E 111/1000 in 19 steps
# Target reached at 17 step
# E 112/1000 in 17 steps
# Target reached at 9 step
# E 113/1000 in 9 steps
# Target reached at 9 step
# E 114/1000 in 9 steps
# Target reached at 18 step
# E 115/1000 in 18 steps
# Target reached at 37 step
# E 116/1000 in 37 steps
# Target reached at 22 step
# E 117/1000 in 22 steps
# Target reached at 26 step
# E 118/1000 in 26 steps
# Target reached at 9 step
# E 119/1000 in 9 steps
# Target reached at 21 step
# E 120/1000 in 21 steps
# Target reached at 40 step
# E 121/1000 in 40 steps
# Target reached at 8 step
# E 122/1000 in 8 steps
# Target reached at 16 step
# E 123/1000 in 16 steps
# Target reached at 8 step
# E 124/1000 in 8 steps
# Target reached at 8 step
# E 125/1000 in 8 steps
# Target reached at 8 step
# E 126/1000 in 8 steps
# Target reached at 9 step
# E 127/1000 in 9 steps
# Target reached at 10 step
# E 128/1000 in 10 steps
# Target reached at 19 step
# E 129/1000 in 19 steps
# Target reached at 23 step
# E 130/1000 in 23 steps
# Target reached at 8 step
# E 131/1000 in 8 steps
# Target reached at 14 step
# E 132/1000 in 14 steps
# Target reached at 9 step
# E 133/1000 in 9 steps
# Target reached at 10 step
# E 134/1000 in 10 steps
# Target reached at 13 step
# E 135/1000 in 13 steps
# Target reached at 17 step
# E 136/1000 in 17 steps
# Target reached at 12 step
# E 137/1000 in 12 steps
# Target reached at 8 step
# E 138/1000 in 8 steps
# Target reached at 9 step
# E 139/1000 in 9 steps
# Target reached at 10 step
# E 140/1000 in 10 steps
# Target reached at 9 step
# E 141/1000 in 9 steps
# Target reached at 27 step
# E 142/1000 in 27 steps
# Target reached at 9 step
# E 143/1000 in 9 steps
# Target reached at 9 step
# E 144/1000 in 9 steps
# Target reached at 16 step
# E 145/1000 in 16 steps
# Target reached at 10 step
# E 146/1000 in 10 steps
# Target reached at 12 step
# E 147/1000 in 12 steps
# Target reached at 8 step
# E 148/1000 in 8 steps
# Target reached at 8 step
# E 149/1000 in 8 steps
# Target reached at 8 step
# E 150/1000 in 8 steps
# Target reached at 34 step
# E 151/1000 in 34 steps
# Target reached at 10 step
# E 152/1000 in 10 steps
# Target reached at 19 step
# E 153/1000 in 19 steps
# Target reached at 22 step
# E 154/1000 in 22 steps
# Target reached at 18 step
# E 155/1000 in 18 steps
# Target reached at 10 step
# E 156/1000 in 10 steps
# Target reached at 14 step
# E 157/1000 in 14 steps
# Target reached at 12 step
# E 158/1000 in 12 steps
# Target reached at 10 step
# E 159/1000 in 10 steps
# Target reached at 12 step
# E 160/1000 in 12 steps
# Target reached at 17 step
# E 161/1000 in 17 steps
# Target reached at 26 step
# E 162/1000 in 26 steps
# Target reached at 10 step
# E 163/1000 in 10 steps
# Target reached at 16 step
# E 164/1000 in 16 steps
# Target reached at 10 step
# E 165/1000 in 10 steps
# Target reached at 10 step
# E 166/1000 in 10 steps
# Target reached at 20 step
# E 167/1000 in 20 steps
# Target reached at 8 step
# E 168/1000 in 8 steps
# Target reached at 10 step
# E 169/1000 in 10 steps
# Target reached at 9 step
# E 170/1000 in 9 steps
# Target reached at 17 step
# E 171/1000 in 17 steps
# Target reached at 8 step
# E 172/1000 in 8 steps
# Target reached at 36 step
# E 173/1000 in 36 steps
# Target reached at 9 step
# E 174/1000 in 9 steps
# Target reached at 14 step
# E 175/1000 in 14 steps
# Target reached at 10 step
# E 176/1000 in 10 steps
# Target reached at 9 step
# E 177/1000 in 9 steps
# Target reached at 13 step
# E 178/1000 in 13 steps
# Target reached at 10 step
# E 179/1000 in 10 steps
# Target reached at 11 step
# E 180/1000 in 11 steps
# Target reached at 13 step
# E 181/1000 in 13 steps
# Target reached at 17 step
# E 182/1000 in 17 steps
# Target reached at 10 step
# E 183/1000 in 10 steps
# Target reached at 26 step
# E 184/1000 in 26 steps
# Target reached at 14 step
# E 185/1000 in 14 steps
# Target reached at 9 step
# E 186/1000 in 9 steps
# Target reached at 14 step
# E 187/1000 in 14 steps
# Target reached at 14 step
# E 188/1000 in 14 steps
# Target reached at 18 step
# E 189/1000 in 18 steps
# Target reached at 10 step
# E 190/1000 in 10 steps
# Target reached at 10 step
# E 191/1000 in 10 steps
# Target reached at 9 step
# E 192/1000 in 9 steps
# Target reached at 14 step
# E 193/1000 in 14 steps
# Target reached at 8 step
# E 194/1000 in 8 steps
# Target reached at 17 step
# E 195/1000 in 17 steps
# Target reached at 10 step
# E 196/1000 in 10 steps
# Target reached at 13 step
# E 197/1000 in 13 steps
# Target reached at 18 step
# E 198/1000 in 18 steps
# Target reached at 9 step
# E 199/1000 in 9 steps
# Target reached at 11 step
# E 200/1000 in 11 steps
# Target reached at 9 step
# E 201/1000 in 9 steps
# Target reached at 21 step
# E 202/1000 in 21 steps
# Target reached at 18 step
# E 203/1000 in 18 steps
# Target reached at 10 step
# E 204/1000 in 10 steps
# Target reached at 9 step
# E 205/1000 in 9 steps
# Target reached at 16 step
# E 206/1000 in 16 steps
# Target reached at 9 step
# E 207/1000 in 9 steps
# Target reached at 24 step
# E 208/1000 in 24 steps
# Target reached at 13 step
# E 209/1000 in 13 steps
# Target reached at 20 step
# E 210/1000 in 20 steps
# Target reached at 11 step
# E 211/1000 in 11 steps
# Target reached at 11 step
# E 212/1000 in 11 steps
# Target reached at 14 step
# E 213/1000 in 14 steps
# Target reached at 14 step
# E 214/1000 in 14 steps
# Target reached at 18 step
# E 215/1000 in 18 steps
# Target reached at 10 step
# E 216/1000 in 10 steps
# Target reached at 18 step
# E 217/1000 in 18 steps
# Target reached at 29 step
# E 218/1000 in 29 steps
# Target reached at 9 step
# E 219/1000 in 9 steps
# Target reached at 9 step
# E 220/1000 in 9 steps
# Target reached at 43 step
# E 221/1000 in 43 steps
# Target reached at 9 step
# E 222/1000 in 9 steps
# Target reached at 8 step
# E 223/1000 in 8 steps
# Target reached at 32 step
# E 224/1000 in 32 steps
# Target reached at 13 step
# E 225/1000 in 13 steps
# Target reached at 12 step
# E 226/1000 in 12 steps
# Target reached at 18 step
# E 227/1000 in 18 steps
# Target reached at 15 step
# E 228/1000 in 15 steps
# Target reached at 8 step
# E 229/1000 in 8 steps
# Target reached at 18 step
# E 230/1000 in 18 steps
# Target reached at 11 step
# E 231/1000 in 11 steps
# Target reached at 12 step
# E 232/1000 in 12 steps
# Target reached at 18 step
# E 233/1000 in 18 steps
# Target reached at 16 step
# E 234/1000 in 16 steps
# Target reached at 16 step
# E 235/1000 in 16 steps
# Target reached at 19 step
# E 236/1000 in 19 steps
# Target reached at 8 step
# E 237/1000 in 8 steps
# Target reached at 8 step
# E 238/1000 in 8 steps
# Target reached at 19 step
# E 239/1000 in 19 steps
# Target reached at 9 step
# E 240/1000 in 9 steps
# Target reached at 10 step
# E 241/1000 in 10 steps
# Target reached at 10 step
# E 242/1000 in 10 steps
# Target reached at 19 step
# E 243/1000 in 19 steps
# Target reached at 19 step
# E 244/1000 in 19 steps
# Target reached at 16 step
# E 245/1000 in 16 steps
# Target reached at 9 step
# E 246/1000 in 9 steps
# Target reached at 10 step
# E 247/1000 in 10 steps
# Target reached at 9 step
# E 248/1000 in 9 steps
# Target reached at 9 step
# E 249/1000 in 9 steps
# Target reached at 10 step
# E 250/1000 in 10 steps
# Target reached at 18 step
# E 251/1000 in 18 steps
# Target reached at 8 step
# E 252/1000 in 8 steps
# Target reached at 9 step
# E 253/1000 in 9 steps
# Target reached at 10 step
# E 254/1000 in 10 steps
# Target reached at 11 step
# E 255/1000 in 11 steps
# Target reached at 8 step
# E 256/1000 in 8 steps
# Target reached at 10 step
# E 257/1000 in 10 steps
# Target reached at 18 step
# E 258/1000 in 18 steps
# Target reached at 10 step
# E 259/1000 in 10 steps
# Target reached at 8 step
# E 260/1000 in 8 steps
# Target reached at 10 step
# E 261/1000 in 10 steps
# Target reached at 10 step
# E 262/1000 in 10 steps
# Target reached at 10 step
# E 263/1000 in 10 steps
# Target reached at 13 step
# E 264/1000 in 13 steps
# Target reached at 10 step
# E 265/1000 in 10 steps
# Target reached at 12 step
# E 266/1000 in 12 steps
# Target reached at 25 step
# E 267/1000 in 25 steps
# Target reached at 25 step
# E 268/1000 in 25 steps
# Target reached at 9 step
# E 269/1000 in 9 steps
# Target reached at 18 step
# E 270/1000 in 18 steps
# Target reached at 11 step
# E 271/1000 in 11 steps
# Target reached at 15 step
# E 272/1000 in 15 steps
# Target reached at 21 step
# E 273/1000 in 21 steps
# Target reached at 9 step
# E 274/1000 in 9 steps
# Target reached at 20 step
# E 275/1000 in 20 steps
# Target reached at 19 step
# E 276/1000 in 19 steps
# Target reached at 14 step
# E 277/1000 in 14 steps
# Target reached at 9 step
# E 278/1000 in 9 steps
# Target reached at 12 step
# E 279/1000 in 12 steps
# Target reached at 10 step
# E 280/1000 in 10 steps
# Target reached at 18 step
# E 281/1000 in 18 steps
# Target reached at 16 step
# E 282/1000 in 16 steps
# Target reached at 14 step
# E 283/1000 in 14 steps
# Target reached at 17 step
# E 284/1000 in 17 steps
# Target reached at 10 step
# E 285/1000 in 10 steps
# Target reached at 17 step
# E 286/1000 in 17 steps
# Target reached at 16 step
# E 287/1000 in 16 steps
# Target reached at 10 step
# E 288/1000 in 10 steps
# Target reached at 20 step
# E 289/1000 in 20 steps
# Target reached at 45 step
# E 290/1000 in 45 steps
# Target reached at 17 step
# E 291/1000 in 17 steps
# Target reached at 46 step
# E 292/1000 in 46 steps
# Target reached at 14 step
# E 293/1000 in 14 steps
# Target reached at 20 step
# E 294/1000 in 20 steps
# Target reached at 10 step
# E 295/1000 in 10 steps
# Target reached at 16 step
# E 296/1000 in 16 steps
# Target reached at 11 step
# E 297/1000 in 11 steps
# Target reached at 15 step
# E 298/1000 in 15 steps
# Target reached at 23 step
# E 299/1000 in 23 steps
# Target reached at 19 step
# E 300/1000 in 19 steps
# Target reached at 13 step
# E 301/1000 in 13 steps
# Target reached at 63 step
# E 302/1000 in 63 steps
# Target reached at 16 step
# E 303/1000 in 16 steps
# Target reached at 17 step
# E 304/1000 in 17 steps
# Target reached at 20 step
# E 305/1000 in 20 steps
# Target reached at 19 step
# E 306/1000 in 19 steps
# Target reached at 16 step
# E 307/1000 in 16 steps
# E 308/1000 in 99 steps
# Target reached at 39 step
# E 309/1000 in 39 steps
# Target reached at 21 step
# E 310/1000 in 21 steps
# Target reached at 39 step
# E 311/1000 in 39 steps
# Target reached at 33 step
# E 312/1000 in 33 steps
# Target reached at 10 step
# E 313/1000 in 10 steps
# Target reached at 11 step
# E 314/1000 in 11 steps
# Target reached at 10 step
# E 315/1000 in 10 steps
# Target reached at 13 step
# E 316/1000 in 13 steps
# Target reached at 9 step
# E 317/1000 in 9 steps
# Target reached at 9 step
# E 318/1000 in 9 steps
# Target reached at 12 step
# E 319/1000 in 12 steps
# Target reached at 9 step
# E 320/1000 in 9 steps
# Target reached at 10 step
# E 321/1000 in 10 steps
# Target reached at 9 step
# E 322/1000 in 9 steps
# Target reached at 9 step
# E 323/1000 in 9 steps
# Target reached at 16 step
# E 324/1000 in 16 steps
# Target reached at 18 step
# E 325/1000 in 18 steps
# Target reached at 29 step
# E 326/1000 in 29 steps
# Target reached at 11 step
# E 327/1000 in 11 steps
# Target reached at 12 step
# E 328/1000 in 12 steps
# Target reached at 11 step
# E 329/1000 in 11 steps
# Target reached at 14 step
# E 330/1000 in 14 steps
# Target reached at 34 step
# E 331/1000 in 34 steps
# Target reached at 11 step
# E 332/1000 in 11 steps
# Target reached at 17 step
# E 333/1000 in 17 steps
# Target reached at 13 step
# E 334/1000 in 13 steps
# Target reached at 24 step
# E 335/1000 in 24 steps
# Target reached at 10 step
# E 336/1000 in 10 steps
# Target reached at 9 step
# E 337/1000 in 9 steps
# Target reached at 10 step
# E 338/1000 in 10 steps
# Target reached at 23 step
# E 339/1000 in 23 steps
# Target reached at 12 step
# E 340/1000 in 12 steps
# Target reached at 40 step
# E 341/1000 in 40 steps
# Target reached at 20 step
# E 342/1000 in 20 steps
# Target reached at 12 step
# E 343/1000 in 12 steps
# Target reached at 12 step
# E 344/1000 in 12 steps
# Target reached at 9 step
# E 345/1000 in 9 steps
# Target reached at 8 step
# E 346/1000 in 8 steps
# Target reached at 8 step
# E 347/1000 in 8 steps
# Target reached at 8 step
# E 348/1000 in 8 steps
# Target reached at 19 step
# E 349/1000 in 19 steps
# Target reached at 10 step
# E 350/1000 in 10 steps
# Target reached at 18 step
# E 351/1000 in 18 steps
# Target reached at 9 step
# E 352/1000 in 9 steps
# Target reached at 14 step
# E 353/1000 in 14 steps
# Target reached at 15 step
# E 354/1000 in 15 steps
# Target reached at 49 step
# E 355/1000 in 49 steps
# Target reached at 15 step
# E 356/1000 in 15 steps
# Target reached at 9 step
# E 357/1000 in 9 steps
# Target reached at 13 step
# E 358/1000 in 13 steps
# Target reached at 16 step
# E 359/1000 in 16 steps
# Target reached at 16 step
# E 360/1000 in 16 steps
# Target reached at 11 step
# E 361/1000 in 11 steps
# Target reached at 17 step
# E 362/1000 in 17 steps
# Target reached at 19 step
# E 363/1000 in 19 steps
# Target reached at 15 step
# E 364/1000 in 15 steps
# Target reached at 10 step
# E 365/1000 in 10 steps
# Target reached at 10 step
# E 366/1000 in 10 steps
# Target reached at 9 step
# E 367/1000 in 9 steps
# Target reached at 8 step
# E 368/1000 in 8 steps
# Target reached at 30 step
# E 369/1000 in 30 steps
# Target reached at 16 step
# E 370/1000 in 16 steps
# Target reached at 8 step
# E 371/1000 in 8 steps
# Target reached at 8 step
# E 372/1000 in 8 steps
# Target reached at 29 step
# E 373/1000 in 29 steps
# Target reached at 12 step
# E 374/1000 in 12 steps
# Target reached at 9 step
# E 375/1000 in 9 steps
# Target reached at 8 step
# E 376/1000 in 8 steps
# Target reached at 17 step
# E 377/1000 in 17 steps
# Target reached at 12 step
# E 378/1000 in 12 steps
# Target reached at 8 step
# E 379/1000 in 8 steps
# Target reached at 11 step
# E 380/1000 in 11 steps
# Target reached at 16 step
# E 381/1000 in 16 steps
# Target reached at 8 step
# E 382/1000 in 8 steps
# Target reached at 8 step
# E 383/1000 in 8 steps
# Target reached at 9 step
# E 384/1000 in 9 steps
# Target reached at 10 step
# E 385/1000 in 10 steps
# Target reached at 9 step
# E 386/1000 in 9 steps
# Target reached at 35 step
# E 387/1000 in 35 steps
# Target reached at 10 step
# E 388/1000 in 10 steps
# Target reached at 13 step
# E 389/1000 in 13 steps
# Target reached at 11 step
# E 390/1000 in 11 steps
# Target reached at 18 step
# E 391/1000 in 18 steps
# Target reached at 14 step
# E 392/1000 in 14 steps
# Target reached at 9 step
# E 393/1000 in 9 steps
# Target reached at 8 step
# E 394/1000 in 8 steps
# Target reached at 8 step
# E 395/1000 in 8 steps
# Target reached at 8 step
# E 396/1000 in 8 steps
# Target reached at 8 step
# E 397/1000 in 8 steps
# Target reached at 8 step
# E 398/1000 in 8 steps
# Target reached at 8 step
# E 399/1000 in 8 steps
# Target reached at 10 step
# E 400/1000 in 10 steps
# Target reached at 8 step
# E 401/1000 in 8 steps
# Target reached at 8 step
# E 402/1000 in 8 steps
# Target reached at 9 step
# E 403/1000 in 9 steps
# Target reached at 8 step
# E 404/1000 in 8 steps
# Target reached at 16 step
# E 405/1000 in 16 steps
# Target reached at 8 step
# E 406/1000 in 8 steps
# Target reached at 8 step
# E 407/1000 in 8 steps
# Target reached at 8 step
# E 408/1000 in 8 steps
# Target reached at 8 step
# E 409/1000 in 8 steps
# Target reached at 8 step
# E 410/1000 in 8 steps
# Target reached at 18 step
# E 411/1000 in 18 steps
# Target reached at 9 step
# E 412/1000 in 9 steps
# Target reached at 9 step
# E 413/1000 in 9 steps
# Target reached at 9 step
# E 414/1000 in 9 steps
# Target reached at 13 step
# E 415/1000 in 13 steps
# Target reached at 8 step
# E 416/1000 in 8 steps
# Target reached at 8 step
# E 417/1000 in 8 steps
# Target reached at 9 step
# E 418/1000 in 9 steps
# Target reached at 16 step
# E 419/1000 in 16 steps
# Target reached at 10 step
# E 420/1000 in 10 steps
# Target reached at 15 step
# E 421/1000 in 15 steps
# Target reached at 10 step
# E 422/1000 in 10 steps
# Target reached at 20 step
# E 423/1000 in 20 steps
# Target reached at 9 step
# E 424/1000 in 9 steps
# Target reached at 9 step
# E 425/1000 in 9 steps
# Target reached at 8 step
# E 426/1000 in 8 steps
# Target reached at 14 step
# E 427/1000 in 14 steps
# Target reached at 8 step
# E 428/1000 in 8 steps
# Target reached at 10 step
# E 429/1000 in 10 steps
# Target reached at 10 step
# E 430/1000 in 10 steps
# Target reached at 8 step
# E 431/1000 in 8 steps
# Target reached at 8 step
# E 432/1000 in 8 steps
# Target reached at 8 step
# E 433/1000 in 8 steps
# Target reached at 8 step
# E 434/1000 in 8 steps
# Target reached at 12 step
# E 435/1000 in 12 steps
# Target reached at 8 step
# E 436/1000 in 8 steps
# Target reached at 9 step
# E 437/1000 in 9 steps
# Target reached at 10 step
# E 438/1000 in 10 steps
# Target reached at 12 step
# E 439/1000 in 12 steps
# Target reached at 8 step
# E 440/1000 in 8 steps
# Target reached at 8 step
# E 441/1000 in 8 steps
# Target reached at 8 step
# E 442/1000 in 8 steps
# Target reached at 8 step
# E 443/1000 in 8 steps
# Target reached at 9 step
# E 444/1000 in 9 steps
# Target reached at 12 step
# E 445/1000 in 12 steps
# Target reached at 9 step
# E 446/1000 in 9 steps
# Target reached at 8 step
# E 447/1000 in 8 steps
# Target reached at 8 step
# E 448/1000 in 8 steps
# Target reached at 9 step
# E 449/1000 in 9 steps
# Target reached at 8 step
# E 450/1000 in 8 steps
# Target reached at 9 step
# E 451/1000 in 9 steps
# Target reached at 8 step
# E 452/1000 in 8 steps
# Target reached at 8 step
# E 453/1000 in 8 steps
# Target reached at 10 step
# E 454/1000 in 10 steps
# Target reached at 16 step
# E 455/1000 in 16 steps
# Target reached at 10 step
# E 456/1000 in 10 steps
# Target reached at 8 step
# E 457/1000 in 8 steps
# Target reached at 9 step
# E 458/1000 in 9 steps
# Target reached at 8 step
# E 459/1000 in 8 steps
# Target reached at 9 step
# E 460/1000 in 9 steps
# Target reached at 8 step
# E 461/1000 in 8 steps
# Target reached at 8 step
# E 462/1000 in 8 steps
# Target reached at 8 step
# E 463/1000 in 8 steps
# Target reached at 40 step
# E 464/1000 in 40 steps
# Target reached at 8 step
# E 465/1000 in 8 steps
# Target reached at 10 step
# E 466/1000 in 10 steps
# Target reached at 8 step
# E 467/1000 in 8 steps
# Target reached at 9 step
# E 468/1000 in 9 steps
# Target reached at 13 step
# E 469/1000 in 13 steps
# Target reached at 8 step
# E 470/1000 in 8 steps
# Target reached at 8 step
# E 471/1000 in 8 steps
# Target reached at 10 step
# E 472/1000 in 10 steps
# Target reached at 8 step
# E 473/1000 in 8 steps
# Target reached at 8 step
# E 474/1000 in 8 steps
# Target reached at 9 step
# E 475/1000 in 9 steps
# Target reached at 14 step
# E 476/1000 in 14 steps
# Target reached at 10 step
# E 477/1000 in 10 steps
# Target reached at 8 step
# E 478/1000 in 8 steps
# Target reached at 8 step
# E 479/1000 in 8 steps
# Target reached at 8 step
# E 480/1000 in 8 steps
# Target reached at 9 step
# E 481/1000 in 9 steps
# Target reached at 8 step
# E 482/1000 in 8 steps
# Target reached at 8 step
# E 483/1000 in 8 steps
# Target reached at 10 step
# E 484/1000 in 10 steps
# Target reached at 9 step
# E 485/1000 in 9 steps
# Target reached at 8 step
# E 486/1000 in 8 steps
# Target reached at 9 step
# E 487/1000 in 9 steps
# Target reached at 8 step
# E 488/1000 in 8 steps
# Target reached at 9 step
# E 489/1000 in 9 steps
# Target reached at 13 step
# E 490/1000 in 13 steps
# Target reached at 8 step
# E 491/1000 in 8 steps
# Target reached at 8 step
# E 492/1000 in 8 steps
# Target reached at 8 step
# E 493/1000 in 8 steps
# Target reached at 8 step
# E 494/1000 in 8 steps
# Target reached at 8 step
# E 495/1000 in 8 steps
# Target reached at 9 step
# E 496/1000 in 9 steps
# Target reached at 8 step
# E 497/1000 in 8 steps
# Target reached at 9 step
# E 498/1000 in 9 steps
# Target reached at 8 step
# E 499/1000 in 8 steps
# Target reached at 10 step
# E 500/1000 in 10 steps
# Target reached at 20 step
# E 501/1000 in 20 steps
# Target reached at 8 step
# E 502/1000 in 8 steps
# Target reached at 13 step
# E 503/1000 in 13 steps
# Target reached at 8 step
# E 504/1000 in 8 steps
# Target reached at 8 step
# E 505/1000 in 8 steps
# Target reached at 8 step
# E 506/1000 in 8 steps
# Target reached at 10 step
# E 507/1000 in 10 steps
# Target reached at 16 step
# E 508/1000 in 16 steps
# Target reached at 9 step
# E 509/1000 in 9 steps
# Target reached at 8 step
# E 510/1000 in 8 steps
# Target reached at 8 step
# E 511/1000 in 8 steps
# Target reached at 14 step
# E 512/1000 in 14 steps
# Target reached at 15 step
# E 513/1000 in 15 steps
# Target reached at 18 step
# E 514/1000 in 18 steps
# Target reached at 18 step
# E 515/1000 in 18 steps
# Target reached at 9 step
# E 516/1000 in 9 steps
# Target reached at 10 step
# E 517/1000 in 10 steps
# Target reached at 8 step
# E 518/1000 in 8 steps
# Target reached at 9 step
# E 519/1000 in 9 steps
# Target reached at 10 step
# E 520/1000 in 10 steps
# Target reached at 11 step
# E 521/1000 in 11 steps
# Target reached at 10 step
# E 522/1000 in 10 steps
# Target reached at 11 step
# E 523/1000 in 11 steps
# Target reached at 15 step
# E 524/1000 in 15 steps
# Target reached at 13 step
# E 525/1000 in 13 steps
# Target reached at 11 step
# E 526/1000 in 11 steps
# Target reached at 8 step
# E 527/1000 in 8 steps
# Target reached at 19 step
# E 528/1000 in 19 steps
# Target reached at 10 step
# E 529/1000 in 10 steps
# Target reached at 20 step
# E 530/1000 in 20 steps
# Target reached at 8 step
# E 531/1000 in 8 steps
# Target reached at 14 step
# E 532/1000 in 14 steps
# Target reached at 10 step
# E 533/1000 in 10 steps
# Target reached at 32 step
# E 534/1000 in 32 steps
# Target reached at 10 step
# E 535/1000 in 10 steps
# Target reached at 8 step
# E 536/1000 in 8 steps
# Target reached at 17 step
# E 537/1000 in 17 steps
# Target reached at 15 step
# E 538/1000 in 15 steps
# Target reached at 10 step
# E 539/1000 in 10 steps
# Target reached at 10 step
# E 540/1000 in 10 steps
# Target reached at 9 step
# E 541/1000 in 9 steps
# Target reached at 11 step
# E 542/1000 in 11 steps
# Target reached at 9 step
# E 543/1000 in 9 steps
# Target reached at 10 step
# E 544/1000 in 10 steps
# Target reached at 9 step
# E 545/1000 in 9 steps
# Target reached at 13 step
# E 546/1000 in 13 steps
# Target reached at 8 step
# E 547/1000 in 8 steps
# Target reached at 12 step
# E 548/1000 in 12 steps
# Target reached at 8 step
# E 549/1000 in 8 steps
# Target reached at 8 step
# E 550/1000 in 8 steps
# Target reached at 8 step
# E 551/1000 in 8 steps
# Target reached at 8 step
# E 552/1000 in 8 steps
# Target reached at 8 step
# E 553/1000 in 8 steps
# Target reached at 9 step
# E 554/1000 in 9 steps
# Target reached at 10 step
# E 555/1000 in 10 steps
# Target reached at 11 step
# E 556/1000 in 11 steps
# Target reached at 8 step
# E 557/1000 in 8 steps
# Target reached at 8 step
# E 558/1000 in 8 steps
# Target reached at 11 step
# E 559/1000 in 11 steps
# Target reached at 10 step
# E 560/1000 in 10 steps
# Target reached at 9 step
# E 561/1000 in 9 steps
# Target reached at 10 step
# E 562/1000 in 10 steps
# Target reached at 8 step
# E 563/1000 in 8 steps
# Target reached at 8 step
# E 564/1000 in 8 steps
# Target reached at 16 step
# E 565/1000 in 16 steps
# Target reached at 8 step
# E 566/1000 in 8 steps
# Target reached at 8 step
# E 567/1000 in 8 steps
# Target reached at 8 step
# E 568/1000 in 8 steps
# Target reached at 9 step
# E 569/1000 in 9 steps
# Target reached at 9 step
# E 570/1000 in 9 steps
# Target reached at 9 step
# E 571/1000 in 9 steps
# Target reached at 9 step
# E 572/1000 in 9 steps
# Target reached at 16 step
# E 573/1000 in 16 steps
# Target reached at 9 step
# E 574/1000 in 9 steps
# Target reached at 9 step
# E 575/1000 in 9 steps
# Target reached at 8 step
# E 576/1000 in 8 steps
# Target reached at 8 step
# E 577/1000 in 8 steps
# Target reached at 9 step
# E 578/1000 in 9 steps
# Target reached at 8 step
# E 579/1000 in 8 steps
# Target reached at 8 step
# E 580/1000 in 8 steps
# Target reached at 8 step
# E 581/1000 in 8 steps
# Target reached at 15 step
# E 582/1000 in 15 steps
# Target reached at 8 step
# E 583/1000 in 8 steps
# Target reached at 9 step
# E 584/1000 in 9 steps
# Target reached at 8 step
# E 585/1000 in 8 steps
# Target reached at 8 step
# E 586/1000 in 8 steps
# Target reached at 9 step
# E 587/1000 in 9 steps
# Target reached at 9 step
# E 588/1000 in 9 steps
# Target reached at 16 step
# E 589/1000 in 16 steps
# Target reached at 8 step
# E 590/1000 in 8 steps
# Target reached at 9 step
# E 591/1000 in 9 steps
# Target reached at 8 step
# E 592/1000 in 8 steps
# Target reached at 12 step
# E 593/1000 in 12 steps
# Target reached at 8 step
# E 594/1000 in 8 steps
# Target reached at 8 step
# E 595/1000 in 8 steps
# Target reached at 9 step
# E 596/1000 in 9 steps
# Target reached at 8 step
# E 597/1000 in 8 steps
# Target reached at 9 step
# E 598/1000 in 9 steps
# Target reached at 9 step
# E 599/1000 in 9 steps
# Target reached at 8 step
# E 600/1000 in 8 steps
# Target reached at 9 step
# E 601/1000 in 9 steps
# Target reached at 15 step
# E 602/1000 in 15 steps
# Target reached at 9 step
# E 603/1000 in 9 steps
# Target reached at 9 step
# E 604/1000 in 9 steps
# Target reached at 13 step
# E 605/1000 in 13 steps
# Target reached at 9 step
# E 606/1000 in 9 steps
# Target reached at 8 step
# E 607/1000 in 8 steps
# Target reached at 28 step
# E 608/1000 in 28 steps
# Target reached at 8 step
# E 609/1000 in 8 steps
# Target reached at 9 step
# E 610/1000 in 9 steps
# Target reached at 9 step
# E 611/1000 in 9 steps
# Target reached at 18 step
# E 612/1000 in 18 steps
# Target reached at 9 step
# E 613/1000 in 9 steps
# Target reached at 8 step
# E 614/1000 in 8 steps
# Target reached at 8 step
# E 615/1000 in 8 steps
# Target reached at 15 step
# E 616/1000 in 15 steps
# Target reached at 9 step
# E 617/1000 in 9 steps
# Target reached at 9 step
# E 618/1000 in 9 steps
# Target reached at 15 step
# E 619/1000 in 15 steps
# Target reached at 9 step
# E 620/1000 in 9 steps
# Target reached at 10 step
# E 621/1000 in 10 steps
# Target reached at 10 step
# E 622/1000 in 10 steps
# Target reached at 9 step
# E 623/1000 in 9 steps
# Target reached at 8 step
# E 624/1000 in 8 steps
# Target reached at 9 step
# E 625/1000 in 9 steps
# Target reached at 9 step
# E 626/1000 in 9 steps
# Target reached at 9 step
# E 627/1000 in 9 steps
# Target reached at 35 step
# E 628/1000 in 35 steps
# Target reached at 9 step
# E 629/1000 in 9 steps
# Target reached at 24 step
# E 630/1000 in 24 steps
# Target reached at 8 step
# E 631/1000 in 8 steps
# Target reached at 8 step
# E 632/1000 in 8 steps
# Target reached at 18 step
# E 633/1000 in 18 steps
# Target reached at 16 step
# E 634/1000 in 16 steps
# Target reached at 8 step
# E 635/1000 in 8 steps
# Target reached at 15 step
# E 636/1000 in 15 steps
# Target reached at 9 step
# E 637/1000 in 9 steps
# Target reached at 8 step
# E 638/1000 in 8 steps
# Target reached at 9 step
# E 639/1000 in 9 steps
# Target reached at 8 step
# E 640/1000 in 8 steps
# Target reached at 9 step
# E 641/1000 in 9 steps
# Target reached at 14 step
# E 642/1000 in 14 steps
# Target reached at 9 step
# E 643/1000 in 9 steps
# Target reached at 9 step
# E 644/1000 in 9 steps
# Target reached at 8 step
# E 645/1000 in 8 steps
# Target reached at 17 step
# E 646/1000 in 17 steps
# Target reached at 25 step
# E 647/1000 in 25 steps
# Target reached at 15 step
# E 648/1000 in 15 steps
# Target reached at 62 step
# E 649/1000 in 62 steps
# Target reached at 8 step
# E 650/1000 in 8 steps
# Target reached at 17 step
# E 651/1000 in 17 steps
# Target reached at 19 step
# E 652/1000 in 19 steps
# Target reached at 8 step
# E 653/1000 in 8 steps
# Target reached at 8 step
# E 654/1000 in 8 steps
# Target reached at 15 step
# E 655/1000 in 15 steps
# Target reached at 22 step
# E 656/1000 in 22 steps
# Target reached at 8 step
# E 657/1000 in 8 steps
# Target reached at 18 step
# E 658/1000 in 18 steps
# Target reached at 10 step
# E 659/1000 in 10 steps
# Target reached at 20 step
# E 660/1000 in 20 steps
# Target reached at 9 step
# E 661/1000 in 9 steps
# Target reached at 9 step
# E 662/1000 in 9 steps
# Target reached at 9 step
# E 663/1000 in 9 steps
# Target reached at 17 step
# E 664/1000 in 17 steps
# Target reached at 9 step
# E 665/1000 in 9 steps
# Target reached at 15 step
# E 666/1000 in 15 steps
# Target reached at 9 step
# E 667/1000 in 9 steps
# Target reached at 8 step
# E 668/1000 in 8 steps
# Target reached at 10 step
# E 669/1000 in 10 steps
# Target reached at 14 step
# E 670/1000 in 14 steps
# Target reached at 23 step
# E 671/1000 in 23 steps
# Target reached at 20 step
# E 672/1000 in 20 steps
# Target reached at 27 step
# E 673/1000 in 27 steps
# Target reached at 14 step
# E 674/1000 in 14 steps
# Target reached at 9 step
# E 675/1000 in 9 steps
# Target reached at 15 step
# E 676/1000 in 15 steps
# Target reached at 9 step
# E 677/1000 in 9 steps
# Target reached at 33 step
# E 678/1000 in 33 steps
# Target reached at 17 step
# E 679/1000 in 17 steps
# Target reached at 15 step
# E 680/1000 in 15 steps
# Target reached at 36 step
# E 681/1000 in 36 steps
# Target reached at 9 step
# E 682/1000 in 9 steps
# Target reached at 14 step
# E 683/1000 in 14 steps
# Target reached at 15 step
# E 684/1000 in 15 steps
# Target reached at 10 step
# E 685/1000 in 10 steps
# Target reached at 9 step
# E 686/1000 in 9 steps
# Target reached at 11 step
# E 687/1000 in 11 steps
# Target reached at 9 step
# E 688/1000 in 9 steps
# Target reached at 16 step
# E 689/1000 in 16 steps
# Target reached at 14 step
# E 690/1000 in 14 steps
# Target reached at 18 step
# E 691/1000 in 18 steps
# Target reached at 9 step
# E 692/1000 in 9 steps
# Target reached at 9 step
# E 693/1000 in 9 steps
# Target reached at 8 step
# E 694/1000 in 8 steps
# Target reached at 9 step
# E 695/1000 in 9 steps
# Target reached at 31 step
# E 696/1000 in 31 steps
# Target reached at 9 step
# E 697/1000 in 9 steps
# Target reached at 18 step
# E 698/1000 in 18 steps
# Target reached at 9 step
# E 699/1000 in 9 steps
# Target reached at 8 step
# E 700/1000 in 8 steps
# Target reached at 9 step
# E 701/1000 in 9 steps
# Target reached at 9 step
# E 702/1000 in 9 steps
# Target reached at 9 step
# E 703/1000 in 9 steps
# Target reached at 8 step
# E 704/1000 in 8 steps
# Target reached at 8 step
# E 705/1000 in 8 steps
# Target reached at 9 step
# E 706/1000 in 9 steps
# Target reached at 8 step
# E 707/1000 in 8 steps
# Target reached at 9 step
# E 708/1000 in 9 steps
# Target reached at 15 step
# E 709/1000 in 15 steps
# Target reached at 9 step
# E 710/1000 in 9 steps
# Target reached at 9 step
# E 711/1000 in 9 steps
# Target reached at 13 step
# E 712/1000 in 13 steps
# Target reached at 8 step
# E 713/1000 in 8 steps
# Target reached at 15 step
# E 714/1000 in 15 steps
# Target reached at 9 step
# E 715/1000 in 9 steps
# Target reached at 9 step
# E 716/1000 in 9 steps
# Target reached at 32 step
# E 717/1000 in 32 steps
# Target reached at 8 step
# E 718/1000 in 8 steps
# Target reached at 10 step
# E 719/1000 in 10 steps
# Target reached at 8 step
# E 720/1000 in 8 steps
# Target reached at 9 step
# E 721/1000 in 9 steps
# Target reached at 8 step
# E 722/1000 in 8 steps
# Target reached at 9 step
# E 723/1000 in 9 steps
# Target reached at 8 step
# E 724/1000 in 8 steps
# Target reached at 9 step
# E 725/1000 in 9 steps
# Target reached at 9 step
# E 726/1000 in 9 steps
# Target reached at 9 step
# E 727/1000 in 9 steps
# Target reached at 8 step
# E 728/1000 in 8 steps
# Target reached at 11 step
# E 729/1000 in 11 steps
# Target reached at 14 step
# E 730/1000 in 14 steps
# Target reached at 16 step
# E 731/1000 in 16 steps
# Target reached at 8 step
# E 732/1000 in 8 steps
# Target reached at 19 step
# E 733/1000 in 19 steps
# Target reached at 8 step
# E 734/1000 in 8 steps
# Target reached at 10 step
# E 735/1000 in 10 steps
# Target reached at 14 step
# E 736/1000 in 14 steps
# Target reached at 10 step
# E 737/1000 in 10 steps
# Target reached at 8 step
# E 738/1000 in 8 steps
# Target reached at 9 step
# E 739/1000 in 9 steps
# Target reached at 8 step
# E 740/1000 in 8 steps
# Target reached at 14 step
# E 741/1000 in 14 steps
# Target reached at 9 step
# E 742/1000 in 9 steps
# Target reached at 8 step
# E 743/1000 in 8 steps
# Target reached at 9 step
# E 744/1000 in 9 steps
# Target reached at 9 step
# E 745/1000 in 9 steps
# Target reached at 9 step
# E 746/1000 in 9 steps
# Target reached at 10 step
# E 747/1000 in 10 steps
# Target reached at 9 step
# E 748/1000 in 9 steps
# Target reached at 29 step
# E 749/1000 in 29 steps
# Target reached at 9 step
# E 750/1000 in 9 steps
# Target reached at 9 step
# E 751/1000 in 9 steps
# Target reached at 8 step
# E 752/1000 in 8 steps
# Target reached at 10 step
# E 753/1000 in 10 steps
# Target reached at 8 step
# E 754/1000 in 8 steps
# Target reached at 8 step
# E 755/1000 in 8 steps
# Target reached at 8 step
# E 756/1000 in 8 steps
# Target reached at 9 step
# E 757/1000 in 9 steps
# Target reached at 8 step
# E 758/1000 in 8 steps
# Target reached at 8 step
# E 759/1000 in 8 steps
# Target reached at 16 step
# E 760/1000 in 16 steps
# Target reached at 8 step
# E 761/1000 in 8 steps
# Target reached at 8 step
# E 762/1000 in 8 steps
# Target reached at 8 step
# E 763/1000 in 8 steps
# Target reached at 9 step
# E 764/1000 in 9 steps
# Target reached at 9 step
# E 765/1000 in 9 steps
# Target reached at 8 step
# E 766/1000 in 8 steps
# Target reached at 8 step
# E 767/1000 in 8 steps
# Target reached at 9 step
# E 768/1000 in 9 steps
# Target reached at 8 step
# E 769/1000 in 8 steps
# Target reached at 14 step
# E 770/1000 in 14 steps
# Target reached at 8 step
# E 771/1000 in 8 steps
# Target reached at 8 step
# E 772/1000 in 8 steps
# Target reached at 14 step
# E 773/1000 in 14 steps
# Target reached at 9 step
# E 774/1000 in 9 steps
# Target reached at 11 step
# E 775/1000 in 11 steps
# Target reached at 8 step
# E 776/1000 in 8 steps
# Target reached at 8 step
# E 777/1000 in 8 steps
# Target reached at 8 step
# E 778/1000 in 8 steps
# Target reached at 8 step
# E 779/1000 in 8 steps
# Target reached at 8 step
# E 780/1000 in 8 steps
# Target reached at 8 step
# E 781/1000 in 8 steps
# Target reached at 9 step
# E 782/1000 in 9 steps
# Target reached at 8 step
# E 783/1000 in 8 steps
# Target reached at 36 step
# E 784/1000 in 36 steps
# Target reached at 9 step
# E 785/1000 in 9 steps
# Target reached at 22 step
# E 786/1000 in 22 steps
# Target reached at 8 step
# E 787/1000 in 8 steps
# Target reached at 29 step
# E 788/1000 in 29 steps
# Target reached at 9 step
# E 789/1000 in 9 steps
# Target reached at 25 step
# E 790/1000 in 25 steps
# Target reached at 8 step
# E 791/1000 in 8 steps
# Target reached at 9 step
# E 792/1000 in 9 steps
# Target reached at 13 step
# E 793/1000 in 13 steps
# Target reached at 9 step
# E 794/1000 in 9 steps
# Target reached at 8 step
# E 795/1000 in 8 steps
# Target reached at 9 step
# E 796/1000 in 9 steps
# Target reached at 8 step
# E 797/1000 in 8 steps
# Target reached at 8 step
# E 798/1000 in 8 steps
# Target reached at 19 step
# E 799/1000 in 19 steps
# Target reached at 8 step
# E 800/1000 in 8 steps
# Target reached at 17 step
# E 801/1000 in 17 steps
# Target reached at 18 step
# E 802/1000 in 18 steps
# Target reached at 9 step
# E 803/1000 in 9 steps
# Target reached at 8 step
# E 804/1000 in 8 steps
# Target reached at 19 step
# E 805/1000 in 19 steps
# Target reached at 9 step
# E 806/1000 in 9 steps
# Target reached at 9 step
# E 807/1000 in 9 steps
# Target reached at 8 step
# E 808/1000 in 8 steps
# Target reached at 9 step
# E 809/1000 in 9 steps
# Target reached at 14 step
# E 810/1000 in 14 steps
# Target reached at 8 step
# E 811/1000 in 8 steps
# Target reached at 8 step
# E 812/1000 in 8 steps
# Target reached at 8 step
# E 813/1000 in 8 steps
# Target reached at 8 step
# E 814/1000 in 8 steps
# Target reached at 8 step
# E 815/1000 in 8 steps
# Target reached at 8 step
# E 816/1000 in 8 steps
# Target reached at 8 step
# E 817/1000 in 8 steps
# Target reached at 8 step
# E 818/1000 in 8 steps
# Target reached at 8 step
# E 819/1000 in 8 steps
# Target reached at 8 step
# E 820/1000 in 8 steps
# Target reached at 8 step
# E 821/1000 in 8 steps
# Target reached at 8 step
# E 822/1000 in 8 steps
# Target reached at 8 step
# E 823/1000 in 8 steps
# Target reached at 8 step
# E 824/1000 in 8 steps
# Target reached at 13 step
# E 825/1000 in 13 steps
# Target reached at 8 step
# E 826/1000 in 8 steps
# Target reached at 9 step
# E 827/1000 in 9 steps
# Target reached at 9 step
# E 828/1000 in 9 steps
# Target reached at 8 step
# E 829/1000 in 8 steps
# Target reached at 15 step
# E 830/1000 in 15 steps
# Target reached at 8 step
# E 831/1000 in 8 steps
# Target reached at 15 step
# E 832/1000 in 15 steps
# Target reached at 9 step
# E 833/1000 in 9 steps
# Target reached at 9 step
# E 834/1000 in 9 steps
# Target reached at 9 step
# E 835/1000 in 9 steps
# Target reached at 13 step
# E 836/1000 in 13 steps
# Target reached at 9 step
# E 837/1000 in 9 steps
# Target reached at 10 step
# E 838/1000 in 10 steps
# Target reached at 8 step
# E 839/1000 in 8 steps
# Target reached at 8 step
# E 840/1000 in 8 steps
# Target reached at 9 step
# E 841/1000 in 9 steps
# Target reached at 8 step
# E 842/1000 in 8 steps
# Target reached at 9 step
# E 843/1000 in 9 steps
# Target reached at 8 step
# E 844/1000 in 8 steps
# Target reached at 8 step
# E 845/1000 in 8 steps
# Target reached at 8 step
# E 846/1000 in 8 steps
# Target reached at 8 step
# E 847/1000 in 8 steps
# Target reached at 9 step
# E 848/1000 in 9 steps
# Target reached at 8 step
# E 849/1000 in 8 steps
# Target reached at 8 step
# E 850/1000 in 8 steps
# Target reached at 8 step
# E 851/1000 in 8 steps
# Target reached at 9 step
# E 852/1000 in 9 steps
# Target reached at 13 step
# E 853/1000 in 13 steps
# Target reached at 8 step
# E 854/1000 in 8 steps
# Target reached at 8 step
# E 855/1000 in 8 steps
# Target reached at 9 step
# E 856/1000 in 9 steps
# Target reached at 9 step
# E 857/1000 in 9 steps
# Target reached at 9 step
# E 858/1000 in 9 steps
# Target reached at 9 step
# E 859/1000 in 9 steps
# Target reached at 8 step
# E 860/1000 in 8 steps
# Target reached at 10 step
# E 861/1000 in 10 steps
# Target reached at 13 step
# E 862/1000 in 13 steps
# Target reached at 24 step
# E 863/1000 in 24 steps
# Target reached at 8 step
# E 864/1000 in 8 steps
# Target reached at 8 step
# E 865/1000 in 8 steps
# Target reached at 11 step
# E 866/1000 in 11 steps
# Target reached at 8 step
# E 867/1000 in 8 steps
# Target reached at 9 step
# E 868/1000 in 9 steps
# Target reached at 8 step
# E 869/1000 in 8 steps
# Target reached at 8 step
# E 870/1000 in 8 steps
# Target reached at 9 step
# E 871/1000 in 9 steps
# Target reached at 8 step
# E 872/1000 in 8 steps
# Target reached at 9 step
# E 873/1000 in 9 steps
# Target reached at 9 step
# E 874/1000 in 9 steps
# Target reached at 9 step
# E 875/1000 in 9 steps
# Target reached at 10 step
# E 876/1000 in 10 steps
# Target reached at 8 step
# E 877/1000 in 8 steps
# Target reached at 8 step
# E 878/1000 in 8 steps
# Target reached at 10 step
# E 879/1000 in 10 steps
# Target reached at 8 step
# E 880/1000 in 8 steps
# Target reached at 15 step
# E 881/1000 in 15 steps
# Target reached at 28 step
# E 882/1000 in 28 steps
# Target reached at 8 step
# E 883/1000 in 8 steps
# Target reached at 9 step
# E 884/1000 in 9 steps
# Target reached at 8 step
# E 885/1000 in 8 steps
# Target reached at 9 step
# E 886/1000 in 9 steps
# Target reached at 9 step
# E 887/1000 in 9 steps
# Target reached at 8 step
# E 888/1000 in 8 steps
# Target reached at 8 step
# E 889/1000 in 8 steps
# Target reached at 8 step
# E 890/1000 in 8 steps
# Target reached at 9 step
# E 891/1000 in 9 steps
# Target reached at 8 step
# E 892/1000 in 8 steps
# Target reached at 9 step
# E 893/1000 in 9 steps
# Target reached at 10 step
# E 894/1000 in 10 steps
# Target reached at 9 step
# E 895/1000 in 9 steps
# Target reached at 9 step
# E 896/1000 in 9 steps
# Target reached at 9 step
# E 897/1000 in 9 steps
# Target reached at 8 step
# E 898/1000 in 8 steps
# Target reached at 9 step
# E 899/1000 in 9 steps
# Target reached at 8 step
# E 900/1000 in 8 steps
# Target reached at 8 step
# E 901/1000 in 8 steps
# Target reached at 23 step
# E 902/1000 in 23 steps
# Target reached at 8 step
# E 903/1000 in 8 steps
# Target reached at 9 step
# E 904/1000 in 9 steps
# Target reached at 8 step
# E 905/1000 in 8 steps
# Target reached at 8 step
# E 906/1000 in 8 steps
# Target reached at 8 step
# E 907/1000 in 8 steps
# Target reached at 8 step
# E 908/1000 in 8 steps
# Target reached at 10 step
# E 909/1000 in 10 steps
# Target reached at 9 step
# E 910/1000 in 9 steps
# Target reached at 9 step
# E 911/1000 in 9 steps
# Target reached at 9 step
# E 912/1000 in 9 steps
# Target reached at 10 step
# E 913/1000 in 10 steps
# Target reached at 8 step
# E 914/1000 in 8 steps
# Target reached at 9 step
# E 915/1000 in 9 steps
# Target reached at 8 step
# E 916/1000 in 8 steps
# Target reached at 8 step
# E 917/1000 in 8 steps
# Target reached at 9 step
# E 918/1000 in 9 steps
# Target reached at 8 step
# E 919/1000 in 8 steps
# Target reached at 8 step
# E 920/1000 in 8 steps
# Target reached at 8 step
# E 921/1000 in 8 steps
# Target reached at 8 step
# E 922/1000 in 8 steps
# Target reached at 8 step
# E 923/1000 in 8 steps
# Target reached at 8 step
# E 924/1000 in 8 steps
# Target reached at 9 step
# E 925/1000 in 9 steps
# Target reached at 8 step
# E 926/1000 in 8 steps
# Target reached at 8 step
# E 927/1000 in 8 steps
# Target reached at 9 step
# E 928/1000 in 9 steps
# Target reached at 16 step
# E 929/1000 in 16 steps
# Target reached at 8 step
# E 930/1000 in 8 steps
# Target reached at 8 step
# E 931/1000 in 8 steps
# Target reached at 8 step
# E 932/1000 in 8 steps
# Target reached at 8 step
# E 933/1000 in 8 steps
# Target reached at 8 step
# E 934/1000 in 8 steps
# Target reached at 8 step
# E 935/1000 in 8 steps
# Target reached at 8 step
# E 936/1000 in 8 steps
# Target reached at 8 step
# E 937/1000 in 8 steps
# Target reached at 14 step
# E 938/1000 in 14 steps
# Target reached at 8 step
# E 939/1000 in 8 steps
# Target reached at 9 step
# E 940/1000 in 9 steps
# Target reached at 9 step
# E 941/1000 in 9 steps
# Target reached at 8 step
# E 942/1000 in 8 steps
# Target reached at 8 step
# E 943/1000 in 8 steps
# Target reached at 9 step
# E 944/1000 in 9 steps
# Target reached at 10 step
# E 945/1000 in 10 steps
# Target reached at 10 step
# E 946/1000 in 10 steps
# Target reached at 8 step
# E 947/1000 in 8 steps
# Target reached at 12 step
# E 948/1000 in 12 steps
# Target reached at 16 step
# E 949/1000 in 16 steps
# Target reached at 13 step
# E 950/1000 in 13 steps
# Target reached at 8 step
# E 951/1000 in 8 steps
# Target reached at 9 step
# E 952/1000 in 9 steps
# Target reached at 9 step
# E 953/1000 in 9 steps
# Target reached at 9 step
# E 954/1000 in 9 steps
# Target reached at 8 step
# E 955/1000 in 8 steps
# Target reached at 14 step
# E 956/1000 in 14 steps
# Target reached at 8 step
# E 957/1000 in 8 steps
# Target reached at 9 step
# E 958/1000 in 9 steps
# Target reached at 8 step
# E 959/1000 in 8 steps
# Target reached at 8 step
# E 960/1000 in 8 steps
# Target reached at 8 step
# E 961/1000 in 8 steps
# Target reached at 8 step
# E 962/1000 in 8 steps
# Target reached at 13 step
# E 963/1000 in 13 steps
# Target reached at 8 step
# E 964/1000 in 8 steps
# Target reached at 8 step
# E 965/1000 in 8 steps
# Target reached at 8 step
# E 966/1000 in 8 steps
# Target reached at 9 step
# E 967/1000 in 9 steps
# Target reached at 9 step
# E 968/1000 in 9 steps
# Target reached at 9 step
# E 969/1000 in 9 steps
# Target reached at 9 step
# E 970/1000 in 9 steps
# Target reached at 8 step
# E 971/1000 in 8 steps
# Target reached at 8 step
# E 972/1000 in 8 steps
# Target reached at 8 step
# E 973/1000 in 8 steps
# Target reached at 9 step
# E 974/1000 in 9 steps
# Target reached at 10 step
# E 975/1000 in 10 steps
# Target reached at 10 step
# E 976/1000 in 10 steps
# Target reached at 8 step
# E 977/1000 in 8 steps
# Target reached at 8 step
# E 978/1000 in 8 steps
# Target reached at 8 step
# E 979/1000 in 8 steps
# Target reached at 10 step
# E 980/1000 in 10 steps
# Target reached at 11 step
# E 981/1000 in 11 steps
# Target reached at 8 step
# E 982/1000 in 8 steps
# Target reached at 8 step
# E 983/1000 in 8 steps
# Target reached at 8 step
# E 984/1000 in 8 steps
# Target reached at 8 step
# E 985/1000 in 8 steps
# Target reached at 9 step
# E 986/1000 in 9 steps
# Target reached at 8 step
# E 987/1000 in 8 steps
# Target reached at 8 step
# E 988/1000 in 8 steps
# Target reached at 8 step
# E 989/1000 in 8 steps
# Target reached at 9 step
# E 990/1000 in 9 steps
# Target reached at 8 step
# E 991/1000 in 8 steps
# Target reached at 9 step
# E 992/1000 in 9 steps
# Target reached at 8 step
# E 993/1000 in 8 steps
# Target reached at 9 step
# E 994/1000 in 9 steps
# Target reached at 11 step
# E 995/1000 in 11 steps
# Target reached at 8 step
# E 996/1000 in 8 steps
# Target reached at 9 step
# E 997/1000 in 9 steps
# Target reached at 9 step
# E 998/1000 in 9 steps
# Target reached at 9 step
# E 999/1000 in 9 steps
# Target reached at 36 step
# E 1000/1000 in 36 steps

# %%
env.plot_trajectory()

# %%
# plot latency to reach goal
plt.figure()
plt.plot(latencys,label='Train')
plt.xlabel('Trial')
plt.ylabel('Latency')
plt.title(f"Steps to reach target")
# Out:
# Text(0.5, 1.0, 'Steps to reach target')
