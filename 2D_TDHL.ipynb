# %% [markdown]
# Code to train an Temporal Difference Error modulated Hebbian Learning (TDHL) agent to navigate to a target in a continuous 2D arena
# Code by: M Ganesh Kumar & Blake Bordeleon
# Date: 02/15/2024

# %%
import numpy as np
import matplotlib.pyplot as plt
from backend import TwoDimNav, PC_AC_agent, plot_maps

# %%
train_episodes = 1000
tmax = 100
goalsize = 0.25
startcoord = [0.0,0.0]
goalcoord = [0.7, 0.7]
testgoalcoord = [-0.7,-0.7]

env = TwoDimNav(startcoord=startcoord, goalcoord=goalcoord, goalsize=goalsize, tmax=tmax)
# Out:
# [0.0, 0.0]

# %%
# initialize agent
alr = 0.001  # 0.0075
clr = 0.005  # 0.025
nact = 4
gamma = 0.95

npc = 21
pc_sigma = 0.25
seed = 2023
agent = PC_AC_agent(alr=alr, clr=clr, npc=npc, pcr=pc_sigma, nact=nact, seed=seed, gamma=gamma)

# %%
# visualize place field at an arbitary coordinate
xy = np.array([0,0])
pc = agent.get_pc(xy)
plt.imshow(pc.reshape(agent.npc, agent.npc))
plt.colorbar()

# %%
latency = []
success = 0
tds = []

for e in range(train_episodes):
    state, goal, eucdist, done = env.reset()

    for t in range(tmax):

        onehotg = agent.get_action(state)

        # eucdist is euclediean distance to goal, done is a sparse scalar reward signal 
        newstate, eucdist, done = env.step(onehotg) 

        # use scalar sparse reward signal to update TD error
        agent.learn(newstate=newstate, reward=done)

        tds.append(agent.td)

        state = newstate.copy()

        if done:
            success+=1
            break
            
    if e % 100 == 0:
        plot_maps(env, npc, agent.wA, agent.wC, title=f'Map at Episode {e+1}')

    latency.append(t)
    #print(agent.wC.max(), agent.wA.max())
    print(f'E {e+1}/{train_episodes} in {t} steps')


print(f"Completion {success}/{train_episodes}")
# Out:
# E 1/1000 in 55 steps
# E 2/1000 in 10 steps
# E 3/1000 in 38 steps
# E 4/1000 in 99 steps
# E 5/1000 in 70 steps
# E 6/1000 in 99 steps
# E 7/1000 in 99 steps
# E 8/1000 in 86 steps
# E 9/1000 in 99 steps
# E 10/1000 in 92 steps
# E 11/1000 in 99 steps
# E 12/1000 in 99 steps
# E 13/1000 in 73 steps
# E 14/1000 in 99 steps
# E 15/1000 in 99 steps
# E 16/1000 in 99 steps
# E 17/1000 in 99 steps
# E 18/1000 in 46 steps
# E 19/1000 in 99 steps
# E 20/1000 in 99 steps
# E 21/1000 in 95 steps
# E 22/1000 in 99 steps
# E 23/1000 in 13 steps
# E 24/1000 in 19 steps
# E 25/1000 in 99 steps
# E 26/1000 in 16 steps
# E 27/1000 in 99 steps
# E 28/1000 in 72 steps
# E 29/1000 in 99 steps
# E 30/1000 in 49 steps
# E 31/1000 in 81 steps
# E 32/1000 in 16 steps
# E 33/1000 in 99 steps
# E 34/1000 in 99 steps
# E 35/1000 in 99 steps
# E 36/1000 in 99 steps
# E 37/1000 in 99 steps
# E 38/1000 in 99 steps
# E 39/1000 in 99 steps
# E 40/1000 in 90 steps
# E 41/1000 in 90 steps
# E 42/1000 in 99 steps
# E 43/1000 in 99 steps
# E 44/1000 in 62 steps
# E 45/1000 in 99 steps
# E 46/1000 in 99 steps
# E 47/1000 in 99 steps
# E 48/1000 in 26 steps
# E 49/1000 in 14 steps
# E 50/1000 in 99 steps
# E 51/1000 in 99 steps
# E 52/1000 in 14 steps
# E 53/1000 in 99 steps
# E 54/1000 in 46 steps
# E 55/1000 in 10 steps
# E 56/1000 in 19 steps
# E 57/1000 in 13 steps
# E 58/1000 in 99 steps
# E 59/1000 in 14 steps
# E 60/1000 in 99 steps
# E 61/1000 in 99 steps
# E 62/1000 in 55 steps
# E 63/1000 in 99 steps
# E 64/1000 in 42 steps
# E 65/1000 in 99 steps
# E 66/1000 in 26 steps
# E 67/1000 in 62 steps
# E 68/1000 in 99 steps
# E 69/1000 in 99 steps
# E 70/1000 in 83 steps
# E 71/1000 in 11 steps
# E 72/1000 in 99 steps
# E 73/1000 in 31 steps
# E 74/1000 in 48 steps
# E 75/1000 in 99 steps
# E 76/1000 in 15 steps
# E 77/1000 in 43 steps
# E 78/1000 in 99 steps
# E 79/1000 in 99 steps
# E 80/1000 in 28 steps
# E 81/1000 in 28 steps
# E 82/1000 in 15 steps
# E 83/1000 in 22 steps
# E 84/1000 in 99 steps
# E 85/1000 in 19 steps
# E 86/1000 in 99 steps
# E 87/1000 in 87 steps
# E 88/1000 in 99 steps
# E 89/1000 in 99 steps
# E 90/1000 in 75 steps
# E 91/1000 in 11 steps
# E 92/1000 in 99 steps
# E 93/1000 in 13 steps
# E 94/1000 in 31 steps
# E 95/1000 in 64 steps
# E 96/1000 in 99 steps
# E 97/1000 in 41 steps
# E 98/1000 in 95 steps
# E 99/1000 in 32 steps
# E 100/1000 in 99 steps
# E 101/1000 in 99 steps
# E 102/1000 in 63 steps
# E 103/1000 in 99 steps
# E 104/1000 in 99 steps
# E 105/1000 in 27 steps
# E 106/1000 in 14 steps
# E 107/1000 in 99 steps
# E 108/1000 in 48 steps
# E 109/1000 in 11 steps
# E 110/1000 in 61 steps
# E 111/1000 in 28 steps
# E 112/1000 in 9 steps
# E 113/1000 in 99 steps
# E 114/1000 in 99 steps
# E 115/1000 in 24 steps
# E 116/1000 in 99 steps
# E 117/1000 in 72 steps
# E 118/1000 in 33 steps
# E 119/1000 in 99 steps
# E 120/1000 in 40 steps
# E 121/1000 in 28 steps
# E 122/1000 in 17 steps
# E 123/1000 in 91 steps
# E 124/1000 in 13 steps
# E 125/1000 in 10 steps
# E 126/1000 in 30 steps
# E 127/1000 in 12 steps
# E 128/1000 in 10 steps
# E 129/1000 in 14 steps
# E 130/1000 in 53 steps
# E 131/1000 in 17 steps
# E 132/1000 in 13 steps
# E 133/1000 in 99 steps
# E 134/1000 in 30 steps
# E 135/1000 in 12 steps
# E 136/1000 in 20 steps
# E 137/1000 in 23 steps
# E 138/1000 in 13 steps
# E 139/1000 in 21 steps
# E 140/1000 in 30 steps
# E 141/1000 in 98 steps
# E 142/1000 in 37 steps
# E 143/1000 in 47 steps
# E 144/1000 in 85 steps
# E 145/1000 in 11 steps
# E 146/1000 in 99 steps
# E 147/1000 in 26 steps
# E 148/1000 in 13 steps
# E 149/1000 in 14 steps
# E 150/1000 in 99 steps
# E 151/1000 in 53 steps
# E 152/1000 in 11 steps
# E 153/1000 in 30 steps
# E 154/1000 in 15 steps
# E 155/1000 in 9 steps
# E 156/1000 in 73 steps
# E 157/1000 in 27 steps
# E 158/1000 in 14 steps
# E 159/1000 in 9 steps
# E 160/1000 in 46 steps
# E 161/1000 in 46 steps
# E 162/1000 in 8 steps
# E 163/1000 in 26 steps
# E 164/1000 in 27 steps
# E 165/1000 in 24 steps
# E 166/1000 in 73 steps
# E 167/1000 in 12 steps
# E 168/1000 in 51 steps
# E 169/1000 in 24 steps
# E 170/1000 in 11 steps
# E 171/1000 in 10 steps
# E 172/1000 in 22 steps
# E 173/1000 in 8 steps
# E 174/1000 in 11 steps
# E 175/1000 in 35 steps
# E 176/1000 in 79 steps
# E 177/1000 in 12 steps
# E 178/1000 in 11 steps
# E 179/1000 in 13 steps
# E 180/1000 in 99 steps
# E 181/1000 in 27 steps
# E 182/1000 in 15 steps
# E 183/1000 in 8 steps
# E 184/1000 in 10 steps
# E 185/1000 in 9 steps
# E 186/1000 in 10 steps
# E 187/1000 in 25 steps
# E 188/1000 in 10 steps
# E 189/1000 in 9 steps
# E 190/1000 in 11 steps
# E 191/1000 in 17 steps
# E 192/1000 in 15 steps
# E 193/1000 in 15 steps
# E 194/1000 in 13 steps
# E 195/1000 in 27 steps
# E 196/1000 in 50 steps
# E 197/1000 in 24 steps
# E 198/1000 in 36 steps
# E 199/1000 in 12 steps
# E 200/1000 in 62 steps
# E 201/1000 in 20 steps
# E 202/1000 in 31 steps
# E 203/1000 in 10 steps
# E 204/1000 in 20 steps
# E 205/1000 in 13 steps
# E 206/1000 in 35 steps
# E 207/1000 in 14 steps
# E 208/1000 in 13 steps
# E 209/1000 in 11 steps
# E 210/1000 in 20 steps
# E 211/1000 in 83 steps
# E 212/1000 in 8 steps
# E 213/1000 in 29 steps
# E 214/1000 in 87 steps
# E 215/1000 in 22 steps
# E 216/1000 in 55 steps
# E 217/1000 in 39 steps
# E 218/1000 in 14 steps
# E 219/1000 in 27 steps
# E 220/1000 in 12 steps
# E 221/1000 in 10 steps
# E 222/1000 in 92 steps
# E 223/1000 in 10 steps
# E 224/1000 in 9 steps
# E 225/1000 in 11 steps
# E 226/1000 in 43 steps
# E 227/1000 in 19 steps
# E 228/1000 in 12 steps
# E 229/1000 in 15 steps
# E 230/1000 in 17 steps
# E 231/1000 in 20 steps
# E 232/1000 in 9 steps
# E 233/1000 in 12 steps
# E 234/1000 in 13 steps
# E 235/1000 in 8 steps
# E 236/1000 in 10 steps
# E 237/1000 in 10 steps
# E 238/1000 in 9 steps
# E 239/1000 in 8 steps
# E 240/1000 in 10 steps
# E 241/1000 in 15 steps
# E 242/1000 in 9 steps
# E 243/1000 in 23 steps
# E 244/1000 in 13 steps
# E 245/1000 in 8 steps
# E 246/1000 in 16 steps
# E 247/1000 in 20 steps
# E 248/1000 in 9 steps
# E 249/1000 in 10 steps
# E 250/1000 in 10 steps
# E 251/1000 in 14 steps
# E 252/1000 in 10 steps
# E 253/1000 in 11 steps
# E 254/1000 in 12 steps
# E 255/1000 in 9 steps
# E 256/1000 in 9 steps
# E 257/1000 in 10 steps
# E 258/1000 in 15 steps
# E 259/1000 in 18 steps
# E 260/1000 in 16 steps
# E 261/1000 in 11 steps
# E 262/1000 in 10 steps
# E 263/1000 in 8 steps
# E 264/1000 in 16 steps
# E 265/1000 in 12 steps
# E 266/1000 in 9 steps
# E 267/1000 in 16 steps
# E 268/1000 in 8 steps
# E 269/1000 in 13 steps
# E 270/1000 in 24 steps
# E 271/1000 in 9 steps
# E 272/1000 in 10 steps
# E 273/1000 in 33 steps
# E 274/1000 in 14 steps
# E 275/1000 in 19 steps
# E 276/1000 in 10 steps
# E 277/1000 in 10 steps
# E 278/1000 in 9 steps
# E 279/1000 in 17 steps
# E 280/1000 in 11 steps
# E 281/1000 in 10 steps
# E 282/1000 in 10 steps
# E 283/1000 in 11 steps
# E 284/1000 in 9 steps
# E 285/1000 in 9 steps
# E 286/1000 in 13 steps
# E 287/1000 in 17 steps
# E 288/1000 in 13 steps
# E 289/1000 in 14 steps
# E 290/1000 in 14 steps
# E 291/1000 in 8 steps
# E 292/1000 in 42 steps
# E 293/1000 in 20 steps
# E 294/1000 in 17 steps
# E 295/1000 in 37 steps
# E 296/1000 in 8 steps
# E 297/1000 in 13 steps
# E 298/1000 in 12 steps
# E 299/1000 in 18 steps
# E 300/1000 in 8 steps
# E 301/1000 in 8 steps
# E 302/1000 in 19 steps
# E 303/1000 in 9 steps
# E 304/1000 in 8 steps
# E 305/1000 in 8 steps
# E 306/1000 in 10 steps
# E 307/1000 in 8 steps
# E 308/1000 in 9 steps
# E 309/1000 in 15 steps
# E 310/1000 in 10 steps
# E 311/1000 in 14 steps
# E 312/1000 in 25 steps
# E 313/1000 in 8 steps
# E 314/1000 in 10 steps
# E 315/1000 in 15 steps
# E 316/1000 in 8 steps
# E 317/1000 in 20 steps
# E 318/1000 in 8 steps
# E 319/1000 in 20 steps
# E 320/1000 in 8 steps
# E 321/1000 in 8 steps
# E 322/1000 in 8 steps
# E 323/1000 in 8 steps
# E 324/1000 in 10 steps
# E 325/1000 in 8 steps
# E 326/1000 in 8 steps
# E 327/1000 in 8 steps
# E 328/1000 in 10 steps
# E 329/1000 in 8 steps
# E 330/1000 in 10 steps
# E 331/1000 in 8 steps
# E 332/1000 in 8 steps
# E 333/1000 in 9 steps
# E 334/1000 in 10 steps
# E 335/1000 in 12 steps
# E 336/1000 in 13 steps
# E 337/1000 in 8 steps
# E 338/1000 in 18 steps
# E 339/1000 in 11 steps
# E 340/1000 in 10 steps
# E 341/1000 in 12 steps
# E 342/1000 in 22 steps
# E 343/1000 in 10 steps
# E 344/1000 in 9 steps
# E 345/1000 in 11 steps
# E 346/1000 in 14 steps
# E 347/1000 in 10 steps
# E 348/1000 in 16 steps
# E 349/1000 in 15 steps
# E 350/1000 in 9 steps
# E 351/1000 in 9 steps
# E 352/1000 in 11 steps
# E 353/1000 in 8 steps
# E 354/1000 in 8 steps
# E 355/1000 in 8 steps
# E 356/1000 in 10 steps
# E 357/1000 in 9 steps
# E 358/1000 in 10 steps
# E 359/1000 in 10 steps
# E 360/1000 in 8 steps
# E 361/1000 in 8 steps
# E 362/1000 in 9 steps
# E 363/1000 in 10 steps
# E 364/1000 in 8 steps
# E 365/1000 in 13 steps
# E 366/1000 in 8 steps
# E 367/1000 in 62 steps
# E 368/1000 in 9 steps
# E 369/1000 in 9 steps
# E 370/1000 in 9 steps
# E 371/1000 in 8 steps
# E 372/1000 in 10 steps
# E 373/1000 in 10 steps
# E 374/1000 in 8 steps
# E 375/1000 in 10 steps
# E 376/1000 in 8 steps
# E 377/1000 in 20 steps
# E 378/1000 in 9 steps
# E 379/1000 in 11 steps
# E 380/1000 in 9 steps
# E 381/1000 in 14 steps
# E 382/1000 in 9 steps
# E 383/1000 in 29 steps
# E 384/1000 in 8 steps
# E 385/1000 in 10 steps
# E 386/1000 in 9 steps
# E 387/1000 in 8 steps
# E 388/1000 in 8 steps
# E 389/1000 in 9 steps
# E 390/1000 in 8 steps
# E 391/1000 in 8 steps
# E 392/1000 in 8 steps
# E 393/1000 in 12 steps
# E 394/1000 in 16 steps
# E 395/1000 in 17 steps
# E 396/1000 in 8 steps
# E 397/1000 in 8 steps
# E 398/1000 in 8 steps
# E 399/1000 in 19 steps
# E 400/1000 in 18 steps
# E 401/1000 in 8 steps
# E 402/1000 in 8 steps
# E 403/1000 in 8 steps
# E 404/1000 in 8 steps
# E 405/1000 in 9 steps
# E 406/1000 in 8 steps
# E 407/1000 in 8 steps
# E 408/1000 in 9 steps
# E 409/1000 in 9 steps
# E 410/1000 in 10 steps
# E 411/1000 in 22 steps
# E 412/1000 in 8 steps
# E 413/1000 in 8 steps
# E 414/1000 in 12 steps
# E 415/1000 in 8 steps
# E 416/1000 in 18 steps
# E 417/1000 in 26 steps
# E 418/1000 in 10 steps
# E 419/1000 in 17 steps
# E 420/1000 in 8 steps
# E 421/1000 in 9 steps
# E 422/1000 in 10 steps
# E 423/1000 in 8 steps
# E 424/1000 in 8 steps
# E 425/1000 in 10 steps
# E 426/1000 in 8 steps
# E 427/1000 in 9 steps
# E 428/1000 in 9 steps
# E 429/1000 in 8 steps
# E 430/1000 in 9 steps
# E 431/1000 in 8 steps
# E 432/1000 in 9 steps
# E 433/1000 in 32 steps
# E 434/1000 in 8 steps
# E 435/1000 in 15 steps
# E 436/1000 in 8 steps
# E 437/1000 in 11 steps
# E 438/1000 in 23 steps
# E 439/1000 in 9 steps
# E 440/1000 in 9 steps
# E 441/1000 in 8 steps
# E 442/1000 in 9 steps
# E 443/1000 in 9 steps
# E 444/1000 in 14 steps
# E 445/1000 in 8 steps
# E 446/1000 in 21 steps
# E 447/1000 in 9 steps
# E 448/1000 in 10 steps
# E 449/1000 in 11 steps
# E 450/1000 in 8 steps
# E 451/1000 in 8 steps
# E 452/1000 in 8 steps
# E 453/1000 in 9 steps
# E 454/1000 in 9 steps
# E 455/1000 in 8 steps
# E 456/1000 in 8 steps
# E 457/1000 in 9 steps
# E 458/1000 in 9 steps
# E 459/1000 in 9 steps
# E 460/1000 in 8 steps
# E 461/1000 in 19 steps
# E 462/1000 in 9 steps
# E 463/1000 in 9 steps
# E 464/1000 in 8 steps
# E 465/1000 in 8 steps
# E 466/1000 in 9 steps
# E 467/1000 in 14 steps
# E 468/1000 in 8 steps
# E 469/1000 in 20 steps
# E 470/1000 in 8 steps
# E 471/1000 in 8 steps
# E 472/1000 in 17 steps
# E 473/1000 in 16 steps
# E 474/1000 in 9 steps
# E 475/1000 in 14 steps
# E 476/1000 in 9 steps
# E 477/1000 in 13 steps
# E 478/1000 in 8 steps
# E 479/1000 in 8 steps
# E 480/1000 in 10 steps
# E 481/1000 in 9 steps
# E 482/1000 in 9 steps
# E 483/1000 in 8 steps
# E 484/1000 in 16 steps
# E 485/1000 in 16 steps
# E 486/1000 in 16 steps
# E 487/1000 in 9 steps
# E 488/1000 in 8 steps
# E 489/1000 in 18 steps
# E 490/1000 in 8 steps
# E 491/1000 in 8 steps
# E 492/1000 in 9 steps
# E 493/1000 in 9 steps
# E 494/1000 in 12 steps
# E 495/1000 in 8 steps
# E 496/1000 in 8 steps
# E 497/1000 in 8 steps
# E 498/1000 in 8 steps
# E 499/1000 in 8 steps
# E 500/1000 in 9 steps
# E 501/1000 in 10 steps
# E 502/1000 in 8 steps
# E 503/1000 in 9 steps
# E 504/1000 in 8 steps
# E 505/1000 in 11 steps
# E 506/1000 in 14 steps
# E 507/1000 in 9 steps
# E 508/1000 in 14 steps
# E 509/1000 in 9 steps
# E 510/1000 in 9 steps
# E 511/1000 in 9 steps
# E 512/1000 in 8 steps
# E 513/1000 in 15 steps
# E 514/1000 in 8 steps
# E 515/1000 in 9 steps
# E 516/1000 in 17 steps
# E 517/1000 in 8 steps
# E 518/1000 in 10 steps
# E 519/1000 in 16 steps
# E 520/1000 in 8 steps
# E 521/1000 in 8 steps
# E 522/1000 in 9 steps
# E 523/1000 in 8 steps
# E 524/1000 in 9 steps
# E 525/1000 in 9 steps
# E 526/1000 in 21 steps
# E 527/1000 in 12 steps
# E 528/1000 in 8 steps
# E 529/1000 in 9 steps
# E 530/1000 in 13 steps
# E 531/1000 in 18 steps
# E 532/1000 in 13 steps
# E 533/1000 in 9 steps
# E 534/1000 in 14 steps
# E 535/1000 in 10 steps
# E 536/1000 in 9 steps
# E 537/1000 in 9 steps
# E 538/1000 in 9 steps
# E 539/1000 in 8 steps
# E 540/1000 in 10 steps
# E 541/1000 in 9 steps
# E 542/1000 in 8 steps
# E 543/1000 in 8 steps
# E 544/1000 in 9 steps
# E 545/1000 in 9 steps
# E 546/1000 in 9 steps
# E 547/1000 in 8 steps
# E 548/1000 in 8 steps
# E 549/1000 in 8 steps
# E 550/1000 in 8 steps
# E 551/1000 in 8 steps
# E 552/1000 in 8 steps
# E 553/1000 in 8 steps
# E 554/1000 in 8 steps
# E 555/1000 in 8 steps
# E 556/1000 in 15 steps
# E 557/1000 in 20 steps
# E 558/1000 in 9 steps
# E 559/1000 in 9 steps
# E 560/1000 in 8 steps
# E 561/1000 in 8 steps
# E 562/1000 in 12 steps
# E 563/1000 in 13 steps
# E 564/1000 in 9 steps
# E 565/1000 in 16 steps
# E 566/1000 in 17 steps
# E 567/1000 in 20 steps
# E 568/1000 in 8 steps
# E 569/1000 in 38 steps
# E 570/1000 in 8 steps
# E 571/1000 in 8 steps
# E 572/1000 in 9 steps
# E 573/1000 in 8 steps
# E 574/1000 in 8 steps
# E 575/1000 in 13 steps
# E 576/1000 in 9 steps
# E 577/1000 in 27 steps
# E 578/1000 in 10 steps
# E 579/1000 in 13 steps
# E 580/1000 in 8 steps
# E 581/1000 in 8 steps
# E 582/1000 in 9 steps
# E 583/1000 in 8 steps
# E 584/1000 in 8 steps
# E 585/1000 in 8 steps
# E 586/1000 in 9 steps
# E 587/1000 in 8 steps
# E 588/1000 in 8 steps
# E 589/1000 in 14 steps
# E 590/1000 in 8 steps
# E 591/1000 in 8 steps
# E 592/1000 in 8 steps
# E 593/1000 in 8 steps
# E 594/1000 in 8 steps
# E 595/1000 in 14 steps
# E 596/1000 in 8 steps
# E 597/1000 in 15 steps
# E 598/1000 in 10 steps
# E 599/1000 in 8 steps
# E 600/1000 in 9 steps
# E 601/1000 in 8 steps
# E 602/1000 in 8 steps
# E 603/1000 in 13 steps
# E 604/1000 in 8 steps
# E 605/1000 in 8 steps
# E 606/1000 in 9 steps
# E 607/1000 in 8 steps
# E 608/1000 in 8 steps
# E 609/1000 in 8 steps
# E 610/1000 in 8 steps
# E 611/1000 in 8 steps
# E 612/1000 in 8 steps
# E 613/1000 in 10 steps
# E 614/1000 in 8 steps
# E 615/1000 in 9 steps
# E 616/1000 in 8 steps
# E 617/1000 in 9 steps
# E 618/1000 in 14 steps
# E 619/1000 in 8 steps
# E 620/1000 in 9 steps
# E 621/1000 in 9 steps
# E 622/1000 in 9 steps
# E 623/1000 in 16 steps
# E 624/1000 in 11 steps
# E 625/1000 in 9 steps
# E 626/1000 in 8 steps
# E 627/1000 in 8 steps
# E 628/1000 in 8 steps
# E 629/1000 in 9 steps
# E 630/1000 in 10 steps
# E 631/1000 in 11 steps
# E 632/1000 in 10 steps
# E 633/1000 in 8 steps
# E 634/1000 in 8 steps
# E 635/1000 in 14 steps
# E 636/1000 in 9 steps
# E 637/1000 in 9 steps
# E 638/1000 in 9 steps
# E 639/1000 in 8 steps
# E 640/1000 in 9 steps
# E 641/1000 in 9 steps
# E 642/1000 in 9 steps
# E 643/1000 in 8 steps
# E 644/1000 in 9 steps
# E 645/1000 in 8 steps
# E 646/1000 in 8 steps
# E 647/1000 in 14 steps
# E 648/1000 in 8 steps
# E 649/1000 in 14 steps
# E 650/1000 in 8 steps
# E 651/1000 in 8 steps
# E 652/1000 in 10 steps
# E 653/1000 in 8 steps
# E 654/1000 in 8 steps
# E 655/1000 in 8 steps
# E 656/1000 in 15 steps
# E 657/1000 in 9 steps
# E 658/1000 in 8 steps
# E 659/1000 in 8 steps
# E 660/1000 in 8 steps
# E 661/1000 in 21 steps
# E 662/1000 in 8 steps
# E 663/1000 in 8 steps
# E 664/1000 in 8 steps
# E 665/1000 in 11 steps
# E 666/1000 in 9 steps
# E 667/1000 in 9 steps
# E 668/1000 in 8 steps
# E 669/1000 in 8 steps
# E 670/1000 in 8 steps
# E 671/1000 in 8 steps
# E 672/1000 in 15 steps
# E 673/1000 in 10 steps
# E 674/1000 in 8 steps
# E 675/1000 in 8 steps
# E 676/1000 in 8 steps
# E 677/1000 in 8 steps
# E 678/1000 in 8 steps
# E 679/1000 in 8 steps
# E 680/1000 in 8 steps
# E 681/1000 in 9 steps
# E 682/1000 in 8 steps
# E 683/1000 in 8 steps
# E 684/1000 in 8 steps
# E 685/1000 in 8 steps
# E 686/1000 in 9 steps
# E 687/1000 in 9 steps
# E 688/1000 in 9 steps
# E 689/1000 in 8 steps
# E 690/1000 in 9 steps
# E 691/1000 in 8 steps
# E 692/1000 in 8 steps
# E 693/1000 in 8 steps
# E 694/1000 in 26 steps
# E 695/1000 in 8 steps
# E 696/1000 in 9 steps
# E 697/1000 in 8 steps
# E 698/1000 in 10 steps
# E 699/1000 in 13 steps
# E 700/1000 in 13 steps
# E 701/1000 in 9 steps
# E 702/1000 in 10 steps
# E 703/1000 in 9 steps
# E 704/1000 in 9 steps
# E 705/1000 in 9 steps
# E 706/1000 in 8 steps
# E 707/1000 in 8 steps
# E 708/1000 in 8 steps
# E 709/1000 in 9 steps
# E 710/1000 in 9 steps
# E 711/1000 in 11 steps
# E 712/1000 in 10 steps
# E 713/1000 in 17 steps
# E 714/1000 in 8 steps
# E 715/1000 in 10 steps
# E 716/1000 in 9 steps
# E 717/1000 in 8 steps
# E 718/1000 in 10 steps
# E 719/1000 in 8 steps
# E 720/1000 in 8 steps
# E 721/1000 in 8 steps
# E 722/1000 in 9 steps
# E 723/1000 in 8 steps
# E 724/1000 in 9 steps
# E 725/1000 in 8 steps
# E 726/1000 in 8 steps
# E 727/1000 in 8 steps
# E 728/1000 in 9 steps
# E 729/1000 in 8 steps
# E 730/1000 in 9 steps
# E 731/1000 in 8 steps
# E 732/1000 in 8 steps
# E 733/1000 in 13 steps
# E 734/1000 in 8 steps
# E 735/1000 in 8 steps
# E 736/1000 in 9 steps
# E 737/1000 in 16 steps
# E 738/1000 in 8 steps
# E 739/1000 in 8 steps
# E 740/1000 in 18 steps
# E 741/1000 in 8 steps
# E 742/1000 in 9 steps
# E 743/1000 in 9 steps
# E 744/1000 in 8 steps
# E 745/1000 in 8 steps
# E 746/1000 in 8 steps
# E 747/1000 in 9 steps
# E 748/1000 in 8 steps
# E 749/1000 in 8 steps
# E 750/1000 in 15 steps
# E 751/1000 in 8 steps
# E 752/1000 in 8 steps
# E 753/1000 in 8 steps
# E 754/1000 in 8 steps
# E 755/1000 in 9 steps
# E 756/1000 in 8 steps
# E 757/1000 in 10 steps
# E 758/1000 in 9 steps
# E 759/1000 in 8 steps
# E 760/1000 in 8 steps
# E 761/1000 in 8 steps
# E 762/1000 in 8 steps
# E 763/1000 in 9 steps
# E 764/1000 in 8 steps
# E 765/1000 in 8 steps
# E 766/1000 in 8 steps
# E 767/1000 in 14 steps
# E 768/1000 in 17 steps
# E 769/1000 in 10 steps
# E 770/1000 in 8 steps
# E 771/1000 in 8 steps
# E 772/1000 in 8 steps
# E 773/1000 in 8 steps
# E 774/1000 in 8 steps
# E 775/1000 in 8 steps
# E 776/1000 in 8 steps
# E 777/1000 in 9 steps
# E 778/1000 in 8 steps
# E 779/1000 in 8 steps
# E 780/1000 in 10 steps
# E 781/1000 in 9 steps
# E 782/1000 in 8 steps
# E 783/1000 in 8 steps
# E 784/1000 in 11 steps
# E 785/1000 in 8 steps
# E 786/1000 in 8 steps
# E 787/1000 in 8 steps
# E 788/1000 in 8 steps
# E 789/1000 in 20 steps
# E 790/1000 in 14 steps
# E 791/1000 in 8 steps
# E 792/1000 in 8 steps
# E 793/1000 in 9 steps
# E 794/1000 in 8 steps
# E 795/1000 in 8 steps
# E 796/1000 in 8 steps
# E 797/1000 in 8 steps
# E 798/1000 in 16 steps
# E 799/1000 in 8 steps
# E 800/1000 in 13 steps
# E 801/1000 in 9 steps
# E 802/1000 in 9 steps
# E 803/1000 in 9 steps
# E 804/1000 in 8 steps
# E 805/1000 in 10 steps
# E 806/1000 in 8 steps
# E 807/1000 in 9 steps
# E 808/1000 in 10 steps
# E 809/1000 in 8 steps
# E 810/1000 in 9 steps
# E 811/1000 in 8 steps
# E 812/1000 in 9 steps
# E 813/1000 in 8 steps
# E 814/1000 in 9 steps
# E 815/1000 in 9 steps
# E 816/1000 in 8 steps
# E 817/1000 in 9 steps
# E 818/1000 in 8 steps
# E 819/1000 in 16 steps
# E 820/1000 in 8 steps
# E 821/1000 in 8 steps
# E 822/1000 in 9 steps
# E 823/1000 in 9 steps
# E 824/1000 in 14 steps
# E 825/1000 in 8 steps
# E 826/1000 in 8 steps
# E 827/1000 in 8 steps
# E 828/1000 in 14 steps
# E 829/1000 in 8 steps
# E 830/1000 in 8 steps
# E 831/1000 in 9 steps
# E 832/1000 in 8 steps
# E 833/1000 in 8 steps
# E 834/1000 in 22 steps
# E 835/1000 in 9 steps
# E 836/1000 in 10 steps
# E 837/1000 in 9 steps
# E 838/1000 in 9 steps
# E 839/1000 in 9 steps
# E 840/1000 in 8 steps
# E 841/1000 in 9 steps
# E 842/1000 in 13 steps
# E 843/1000 in 8 steps
# E 844/1000 in 8 steps
# E 845/1000 in 8 steps
# E 846/1000 in 8 steps
# E 847/1000 in 9 steps
# E 848/1000 in 9 steps
# E 849/1000 in 9 steps
# E 850/1000 in 8 steps
# E 851/1000 in 9 steps
# E 852/1000 in 29 steps
# E 853/1000 in 9 steps
# E 854/1000 in 8 steps
# E 855/1000 in 8 steps
# E 856/1000 in 8 steps
# E 857/1000 in 8 steps
# E 858/1000 in 8 steps
# E 859/1000 in 8 steps
# E 860/1000 in 9 steps
# E 861/1000 in 8 steps
# E 862/1000 in 8 steps
# E 863/1000 in 8 steps
# E 864/1000 in 9 steps
# E 865/1000 in 9 steps
# E 866/1000 in 8 steps
# E 867/1000 in 8 steps
# E 868/1000 in 9 steps
# E 869/1000 in 9 steps
# E 870/1000 in 9 steps
# E 871/1000 in 8 steps
# E 872/1000 in 8 steps
# E 873/1000 in 8 steps
# E 874/1000 in 11 steps
# E 875/1000 in 9 steps
# E 876/1000 in 8 steps
# E 877/1000 in 9 steps
# E 878/1000 in 8 steps
# E 879/1000 in 8 steps
# E 880/1000 in 8 steps
# E 881/1000 in 8 steps
# E 882/1000 in 9 steps
# E 883/1000 in 9 steps
# E 884/1000 in 10 steps
# E 885/1000 in 8 steps
# E 886/1000 in 9 steps
# E 887/1000 in 16 steps
# E 888/1000 in 8 steps
# E 889/1000 in 8 steps
# E 890/1000 in 8 steps
# E 891/1000 in 9 steps
# E 892/1000 in 8 steps
# E 893/1000 in 9 steps
# E 894/1000 in 8 steps
# E 895/1000 in 8 steps
# E 896/1000 in 8 steps
# E 897/1000 in 8 steps
# E 898/1000 in 8 steps
# E 899/1000 in 8 steps
# E 900/1000 in 8 steps
# E 901/1000 in 8 steps
# E 902/1000 in 10 steps
# E 903/1000 in 8 steps
# E 904/1000 in 8 steps
# E 905/1000 in 8 steps
# E 906/1000 in 8 steps
# E 907/1000 in 9 steps
# E 908/1000 in 9 steps
# E 909/1000 in 9 steps
# E 910/1000 in 9 steps
# E 911/1000 in 8 steps
# E 912/1000 in 8 steps
# E 913/1000 in 8 steps
# E 914/1000 in 8 steps
# E 915/1000 in 8 steps
# E 916/1000 in 10 steps
# E 917/1000 in 9 steps
# E 918/1000 in 8 steps
# E 919/1000 in 10 steps
# E 920/1000 in 9 steps
# E 921/1000 in 9 steps
# E 922/1000 in 8 steps
# E 923/1000 in 8 steps
# E 924/1000 in 8 steps
# E 925/1000 in 8 steps
# E 926/1000 in 8 steps
# E 927/1000 in 8 steps
# E 928/1000 in 8 steps
# E 929/1000 in 8 steps
# E 930/1000 in 8 steps
# E 931/1000 in 8 steps
# E 932/1000 in 9 steps
# E 933/1000 in 8 steps
# E 934/1000 in 15 steps
# E 935/1000 in 8 steps
# E 936/1000 in 8 steps
# E 937/1000 in 9 steps
# E 938/1000 in 10 steps
# E 939/1000 in 8 steps
# E 940/1000 in 8 steps
# E 941/1000 in 9 steps
# E 942/1000 in 9 steps
# E 943/1000 in 8 steps
# E 944/1000 in 10 steps
# E 945/1000 in 8 steps
# E 946/1000 in 8 steps
# E 947/1000 in 8 steps
# E 948/1000 in 8 steps
# E 949/1000 in 9 steps
# E 950/1000 in 8 steps
# E 951/1000 in 8 steps
# E 952/1000 in 9 steps
# E 953/1000 in 8 steps
# E 954/1000 in 8 steps
# E 955/1000 in 13 steps
# E 956/1000 in 9 steps
# E 957/1000 in 8 steps
# E 958/1000 in 9 steps
# E 959/1000 in 8 steps
# E 960/1000 in 8 steps
# E 961/1000 in 8 steps
# E 962/1000 in 9 steps
# E 963/1000 in 8 steps
# E 964/1000 in 8 steps
# E 965/1000 in 8 steps
# E 966/1000 in 8 steps
# E 967/1000 in 13 steps
# E 968/1000 in 8 steps
# E 969/1000 in 9 steps
# E 970/1000 in 8 steps
# E 971/1000 in 8 steps
# E 972/1000 in 8 steps
# E 973/1000 in 9 steps
# E 974/1000 in 8 steps
# E 975/1000 in 9 steps
# E 976/1000 in 8 steps
# E 977/1000 in 8 steps
# E 978/1000 in 8 steps
# E 979/1000 in 9 steps
# E 980/1000 in 8 steps
# E 981/1000 in 11 steps
# E 982/1000 in 8 steps
# E 983/1000 in 9 steps
# E 984/1000 in 15 steps
# E 985/1000 in 8 steps
# E 986/1000 in 8 steps
# E 987/1000 in 8 steps
# E 988/1000 in 9 steps
# E 989/1000 in 8 steps
# E 990/1000 in 9 steps
# E 991/1000 in 8 steps
# E 992/1000 in 8 steps
# E 993/1000 in 10 steps
# E 994/1000 in 9 steps
# E 995/1000 in 8 steps
# E 996/1000 in 8 steps
# E 997/1000 in 10 steps
# E 998/1000 in 8 steps
# E 999/1000 in 8 steps
# E 1000/1000 in 8 steps
# Completion 939/1000

# %%
env.plot_trajectory()

# %%
# plot latency to reach goal
plt.figure()
plt.plot(latency,label='Train')
plt.xlabel('Trial')
plt.ylabel('Latency')
plt.title(f"Steps to reach target")
# Out:
# Text(0.5, 1.0, 'Steps to reach target')
